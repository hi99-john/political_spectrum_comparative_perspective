# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as st

# %% [markdown]
# # The class, the object, the data and the methods

# %% [markdown]
# ## Defining the class

# %%
class CountryLevelDataAnalysis:
    def loading_country_level_predictors(self):
        self.predictors = pd.read_csv('./country_level_processed_data/country_predictors.csv')
        
    def loading_country_level_correlations(self):
        self.correlations = pd.read_csv('./country_level_processed_data/country_correlations.csv')
        
    def renaming_country_column(self):
        self.correlations.columns = ['iso_numeric', 'freedom_socialism', 'freedom_family', 'freedom_ethnicity', 'freedom_gender', 'freedom_nationalism', 'freedom_religiosity',
        'socialism_family', 'socialism_ethnicity', 'socialism_gender', 'socialism_nationalism', 'socialism_religiosity', 
        'family_ethnicity', 'family_gender', 'family_nationalism', 'family_religiosity', 
        'ethnicity_gender', 'ethnicity_nationalism', 'ethnicity_religiosity', 
        'gender_nationalism', 'gender_religiosity', 
        'nationalism_religiosity']
        
    def merging_data_frames(self):
        self.predictors_correlations = pd.merge(self.predictors, self.correlations, on ='iso_numeric')
        
    def saving_merged_data(self):
        self.predictors_correlations.to_csv('./country_level_processed_data/predictors_correlations.csv', sep=',', index=True, encoding='utf-8')
        
    def regression_sklearn(self):
        self.correlation_names = ['freedom_socialism', 'freedom_family', 'freedom_ethnicity', 'freedom_gender', 'freedom_nationalism', 'freedom_religiosity',
        'socialism_family', 'socialism_ethnicity', 'socialism_gender', 'socialism_nationalism', 'socialism_religiosity', 
        'family_ethnicity', 'family_gender', 'family_nationalism', 'family_religiosity', 
        'ethnicity_gender', 'ethnicity_nationalism', 'ethnicity_religiosity', 
        'gender_nationalism', 'gender_religiosity', 
        'nationalism_religiosity']
        for i in self.correlation_names:
            exec(f"self.{i}_and_predictors = self.predictors_correlations[['authoritarian_socialism', 'culture_zone', 'hdi2010', 'v2x_libdem', '{i}']]")
            exec(f'self.{i}_and_predictors_clean = self.{i}_and_predictors.dropna()')
            exec(f"self.x = np.array(self.{i}_and_predictors_clean[['authoritarian_socialism', 'culture_zone', 'hdi2010', 'v2x_libdem']])")
            exec(f"self.y = np.array(self.{i}_and_predictors_clean[['{i}']])")
            exec(f'self.{i}_sklearn_model = LinearRegression()')
            exec(f'self.{i}_sklearn_model.fit(self.x, self.y)')
            exec(f'self.{i}_sklearn_score = self.{i}_sklearn_model.score(self.x, self.y)')
    
    def regression_statsmodels(self):
        self.correlation_names = ['freedom_socialism', 'freedom_family', 'freedom_ethnicity', 'freedom_gender', 'freedom_nationalism', 'freedom_religiosity',
        'socialism_family', 'socialism_ethnicity', 'socialism_gender', 'socialism_nationalism', 'socialism_religiosity', 
        'family_ethnicity', 'family_gender', 'family_nationalism', 'family_religiosity', 
        'ethnicity_gender', 'ethnicity_nationalism', 'ethnicity_religiosity', 
        'gender_nationalism', 'gender_religiosity', 
        'nationalism_religiosity']
        for i in self.correlation_names:
            exec(f"self.{i}_and_predictors = self.predictors_correlations[['authoritarian_socialism', 'culture_zone', 'hdi2010', 'v2x_libdem', '{i}']]")
            exec(f"self.{i}_and_predictors_clean = self.{i}_and_predictors.dropna()")
            exec(f"self.x = self.{i}_and_predictors_clean[['authoritarian_socialism', 'culture_zone', 'hdi2010', 'v2x_libdem']]")
            exec(f"self.y = self.{i}_and_predictors_clean['{i}']")
            exec(f"self.x = st.add_constant(self.x)")
            exec(f"self.{i}_statsmodels_model = st.OLS(self.y, self.x).fit()")

# %% [markdown]
# ## Instantiating the class

# %%
CountryLevelDataAnalyzer = CountryLevelDataAnalysis()

# %% [markdown]
# ## Caling the methods

# %%
CountryLevelDataAnalyzer.loading_country_level_predictors()

# %%
CountryLevelDataAnalyzer.loading_country_level_correlations()

# %%
CountryLevelDataAnalyzer.renaming_country_column()

# %%
CountryLevelDataAnalyzer.merging_data_frames()

# %%
CountryLevelDataAnalyzer.saving_merged_data()

# %%
CountryLevelDataAnalyzer.regression_sklearn()

# %%
CountryLevelDataAnalyzer.regression_statsmodels()

# %% [markdown]
# # The results

# %% [markdown]
# ## The loading_country_level_predictors(), loading_country_level_correlations() and  renaming_country_column() methods

# %%
CountryLevelDataAnalyzer.predictors
# Out:
#      iso_numeric iso_alpha_2 iso_alpha3 country_name  authoritarian_socialism  \
# 0              8          AL        ALB      Albania                      1.0
# 1             12          DZ        DZA      Algeria                      0.5
# 2             31          AZ        AZE   Azerbaijan                      1.0
# 3             32          AR        ARG    Argentina                      0.0
# 4             36          AU        AUS    Australia                      0.0
# ..           ...         ...        ...          ...                      ...
# 101          858          UY        URY      Uruguay                      0.0
# 102          860          UZ        UZB   Uzbekistan                      1.0
# 103          862          VE        VEN    Venezuela                      0.5
# 104          887          YE        YEM        Yemen                      0.0
# 105          894          ZM        ZMB       Zambia                      0.5
#
#      culture_zone  hdi2010  v2x_libdem
# 0            0.00    0.677       0.341
# 1            0.00    0.649       0.162
# 2            0.00    0.622       0.084
# 3            0.33    0.779       0.662
# 4            1.00    0.896       0.849
# ..            ...      ...         ...
# 101          0.33    0.753       0.801
# 102          0.00    0.607       0.035
# 103          0.33    0.684       0.312
# 104          0.00    0.450       0.138
# 105          0.00    0.418       0.388
#
# [106 rows x 8 columns]

# %%
CountryLevelDataAnalyzer.correlations
# Out:
#      iso_numeric  freedom_socialism  freedom_family  freedom_ethnicity  \
# 0              8              -0.05            0.07               0.06
# 1             12              -0.15            0.04              -0.00
# 2             20               0.07            0.32               0.06
# 3             31              -0.01            0.05               0.03
# 4             32              -0.04            0.28               0.18
# ..           ...                ...             ...                ...
# 113          862              -0.01            0.08               0.01
# 114          887               0.10            0.21               0.01
# 115          894               0.07            0.08               0.02
# 116          909               0.01            0.43               0.19
# 117          915                NaN             NaN                NaN
#
#      freedom_gender  freedom_nationalism  freedom_religiosity  \
# 0              0.11                -0.04                -0.07
# 1              0.03                -0.11                -0.05
# 2              0.20                -0.17                -0.10
# 3              0.04                -0.06                -0.08
# 4              0.22                -0.19                -0.14
# ..              ...                  ...                  ...
# 113            0.09                -0.02                -0.04
# 114            0.20                -0.22                -0.29
# 115            0.02                -0.25                -0.19
# 116            0.21                  NaN                -0.09
# 117             NaN                  NaN                  NaN
#
#      socialism_family  socialism_ethnicity  socialism_gender  ...  \
# 0               -0.11                -0.05              0.05  ...
# 1                0.05                  NaN              0.02  ...
# 2               -0.02                 0.10              0.00  ...
# 3               -0.02                -0.09             -0.01  ...
# 4                0.05                 0.02             -0.01  ...
# ..                ...                  ...               ...  ...
# 113             -0.03                 0.00             -0.00  ...
# 114              0.12                 0.01              0.05  ...
# 115              0.24                -0.03             -0.12  ...
# 116             -0.04                -0.13              0.06  ...
# 117              0.04                 0.02               NaN  ...
#
#      family_ethnicity  family_gender  family_nationalism  family_religiosity  \
# 0                0.12           0.01               -0.22               -0.17
# 1                0.11           0.03               -0.09               -0.10
# 2                0.04           0.26               -0.15               -0.40
# 3                0.14           0.15               -0.04               -0.17
# 4                0.12           0.24               -0.14               -0.32
# ..                ...            ...                 ...                 ...
# 113              0.10           0.07               -0.15               -0.18
# 114             -0.03           0.05               -0.05               -0.19
# 115             -0.07          -0.03               -0.00               -0.06
# 116              0.11           0.32                0.02               -0.38
# 117             -0.10            NaN                 NaN               -0.07
#
#      ethnicity_gender  ethnicity_nationalism  ethnicity_religiosity  \
# 0                0.22                  -0.02                  -0.05
# 1                0.18                    NaN                  -0.01
# 2                0.08                  -0.12                  -0.10
# 3                0.02                   0.12                  -0.02
# 4                0.20                  -0.11                  -0.08
# ..                ...                    ...                    ...
# 113              0.12                  -0.09                  -0.05
# 114              0.24                  -0.13                  -0.14
# 115              0.13                   0.07                   0.03
# 116              0.23                  -0.17                  -0.01
# 117               NaN                    NaN                  -0.10
#
#      gender_nationalism  gender_religiosity  nationalism_religiosity
# 0                  0.11               -0.10                    -0.00
# 1                 -0.03               -0.10                     0.15
# 2                 -0.05               -0.15                     0.13
# 3                 -0.07               -0.10                     0.10
# 4                 -0.09               -0.10                     0.17
# ..                  ...                 ...                      ...
# 113               -0.02                0.01                     0.08
# 114               -0.10               -0.29                     0.17
# 115                0.03                0.16                     0.22
# 116                 NaN               -0.12                    -0.07
# 117                 NaN                 NaN                      NaN
#
# [118 rows x 22 columns]

# %% [markdown]
# ## The merging_data_frames() method

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
CountryLevelDataAnalyzer.predictors_correlations
# Out:
#      iso_numeric iso_alpha_2 iso_alpha3            country_name  \
# 0              8          AL        ALB                 Albania
# 1             12          DZ        DZA                 Algeria
# 2             31          AZ        AZE              Azerbaijan
# 3             32          AR        ARG               Argentina
# 4             36          AU        AUS               Australia
# 5             40          AT        AUT                 Austria
# 6             50          BD        BGD              Bangladesh
# 7             51          AM        ARM                 Armenia
# 8             56          BE        BEL                 Belgium
# 9             68          BO        BOL                 Bolivia
# 10            70          BA        BIH  Bosnia and Herzegovina
# 11            76          BR        BRA                  Brazil
# 12           100          BR        BGR                Bulgaria
# 13           104          MM        MMR                 Myanmar
# 14           112          BY        BLR                 Belarus
# 15           124          CA        CAN                  Canada
# 16           152          CL        CHL                   Chile
# 17           156          CN        CHN                   China
# 18           170          CO        COL                Colombia
# 19           191          HR        HRV                 Croatia
# 20           196          CY        CYP                  Cyprus
# 21           203          CZ        CZE          Czech Republic
# 22           208          DK        DNK                 Denmark
# 23           214          DO        DOM      Dominican Republic
# 24           218          EC        ECU                 Ecuador
# 25           222          SV        SLV             El Salvador
# 26           231          ET        ETH                Ethiopia
# 27           233          EE        EST                 Estonia
# 28           246          FI        FIN                 Finland
# 29           250          FR        FRA                  France
# 30           268          GE        GEO                 Georgia
# 31           276          DE        DEU                 Germany
# 32           288          GH        GHA                   Ghana
# 33           300          GR        GRC                  Greece
# 34           320          GT        GTM               Guatemala
# 35           332          HT        HTI                   Haiti
# 36           344          HK        HKG               Hong Kong
# 37           348          HU        HUN                 Hungary
# 38           352          IS        ISL                 Iceland
# 39           356          IN        IND                   India
# 40           360          ID        IDN               Indonesia
# 41           364          IR        IRN                    Iran
# 42           368          IQ        IRQ                    Iraq
# 43           372          IE        IRL                 Ireland
# 44           376          IL        ISR                  Israel
# 45           380          IT        ITA                   Italy
# 46           392          JP        JPN                   Japan
# 47           398          KZ        KAZ              Kazakhstan
# 48           400          JO        JOR                  Jordan
# 49           404          KE        KEN                   Kenya
# 50           410          KR        KOR             South Korea
# 51           414          KW        KWT                  Kuwait
# 52           417          KG        KGZ              Kyrgyzstan
# 53           428          LV        LVA                  Latvia
# 54           434          LY        LBY                   Libya
# 55           440          LT        LTU               Lithuania
# 56           442          LU        LUX              Luxembourg
# 57           458          MY        MYS                Malaysia
# 58           462          MV        MDV                Maldives
# 59           466          ML        MLI                    Mali
# 60           470          MT        MLT                   Malta
# 61           484          MX        MEX                  Mexico
# 62           496          MN        MNG                Mongolia
# 63           498          MD        MDA                 Moldova
# 64           504          MA        MAR                 Morocco
# 65           528          NL        NLD             Netherlands
# 66           554          NZ        NZL            New Zealand
# 67           558          NI        NIC               Nicaragua
# 68           578          NO        NOR                  Norway
# 69           586          PK        PAK                Pakistan
# 70           604          PE        PER                    Peru
# 71           608          PH        PHL             Philippines
# 72           616          PL        POL                  Poland
# 73           620          PT        PRT                Portugal
# 74           634          QA        QAT                   Qatar
# 75           642          RO        ROU                 Romania
# 76           646          RW        RWA                  Rwanda
# 77           682          SA        SAU            Saudi Arabia
# 78           688          RS        SRB                  Serbia
# 79           702          SG        SGP               Singapore
# 80           703          SK        SVK                Slovakia
# 81           704          VN        VNM                Vietnam
# 82           705          SI        SVN                Slovenia
# 83           710         ZA         ZAF            South Africa
# 84           716          ZW        ZWE                Zimbabwe
# 85           724          ES        ESP                   Spain
# 86           752          SE        SWE                  Sweden
# 87           756          CH        CHE             Switzerland
# 88           762          TJ        TJK              Tajikistan
# 89           764          TH        THA                Thailand
# 90           780          TT        TTO     Trinidad and Tobago
# 91           788          TN        TUN                 Tunisia
# 92           792          TR        TUR                  Turkey
# 93           800          UG        UGA                  Uganda
# 94           804          UA        UKR                 Ukraine
# 95           807          MK        MKD         North Macedonia
# 96           818          EG        EGY                   Egypt
# 97           826          GB        GBR          United Kingdom
# 98           834          TZ        TZA                Tanzania
# 99           840          US        USA           United States
# 100          854          BF        BFA            Burkina Faso
# 101          858          UY        URY                 Uruguay
# 102          860          UZ        UZB              Uzbekistan
# 103          862          VE        VEN               Venezuela
# 104          887          YE        YEM                   Yemen
# 105          894          ZM        ZMB                  Zambia
#
#      authoritarian_socialism  culture_zone  hdi2010  v2x_libdem  \
# 0                        1.0          0.00    0.677       0.341
# 1                        0.5          0.00    0.649       0.162
# 2                        1.0          0.00    0.622       0.084
# 3                        0.0          0.33    0.779       0.662
# 4                        0.0          1.00    0.896       0.849
# 5                        0.0          0.66    0.871       0.785
# 6                        0.0          0.00    0.485       0.281
# 7                        1.0          0.00    0.662       0.214
# 8                        0.0          0.66    0.887       0.819
# 9                        0.0          0.33    0.632       0.530
# 10                       1.0          0.00    0.667       0.421
# 11                       0.0          0.33    0.679       0.735
# 12                       1.0          0.00    0.725       0.630
# 13                       0.5          0.00    0.410       0.018
# 14                       1.0          0.00    0.712       0.111
# 15                       0.0          1.00    0.890       0.759
# 16                       0.0          0.33    0.763       0.816
# 17                       1.0          0.00    0.584       0.063
# 18                       0.0          0.33    0.666       0.423
# 19                       1.0          0.00    0.759       0.626
# 20                       0.0          0.00    0.797       0.671
# 21                       1.0          0.00    0.808       0.810
# 22                       0.0          0.66    0.889       0.881
# 23                       0.0          0.33    0.646       0.365
# 24                       0.0          0.33    0.687       0.466
# 25                       0.0          0.33    0.617       0.324
# 26                       1.0          0.00    0.287       0.111
# 27                       1.0          0.00    0.787       0.804
# 28                       1.0          0.66    0.891       0.828
# 29                       1.0          0.66    0.844       0.803
# 30                       1.0          0.00    0.702       0.208
# 31                       1.0          0.66    0.889       0.866
# 32                       0.5          0.00    0.507       0.573
# 33                       0.0          0.00    0.810       0.798
# 34                       0.0          0.33    0.550       0.376
# 35                       0.0          0.33    0.470       0.273
# 36                       0.0          0.00    0.851       0.317
# 37                       1.0          0.00    0.773       0.756
# 38                       0.0          0.66    0.871       0.789
# 39                       0.0          0.00    0.491       0.584
# 40                       0.0          0.00    0.595       0.511
# 41                       0.0          0.00    0.685       0.173
# 42                       0.5          0.00    0.589       0.068
# 43                       0.0          1.00    0.847       0.816
# 44                       0.0          0.00    0.844       0.696
# 45                       0.0          0.66    0.841       0.763
# 46                       0.0          0.00    0.877       0.762
# 47                       1.0          0.00    0.680       0.133
# 48                       0.0          0.00    0.678       0.132
# 49                       0.0          0.00    0.481       0.251
# 50                       0.0          0.00    0.825       0.771
# 51                       0.0          0.00    0.787       0.279
# 52                       1.0          0.00    0.621       0.164
# 53                       1.0          0.00    0.756       0.705
# 54                       0.5          0.00    0.712       0.050
# 55                       1.0          0.00    0.766       0.765
# 56                       0.0          0.66    0.864       0.796
# 57                       0.0          0.00    0.721       0.165
# 58                       0.0          0.00    0.628       0.059
# 59                       0.5          0.00    0.317       0.374
# 60                       0.0          0.66    0.779       0.616
# 61                       0.0          0.33    0.709       0.480
# 62                       1.0          0.00    0.598       0.559
# 63                       1.0          0.00    0.641       0.448
# 64                       0.0          0.00    0.521       0.217
# 65                       0.0          0.66    0.893       0.808
# 66                       0.0          1.00    0.887       0.834
# 67                       0.5          0.33    0.566       0.381
# 68                       0.0          1.00    0.913       0.858
# 69                       0.0          0.00    0.441       0.094
# 70                       0.0          0.33    0.676       0.195
# 71                       0.0          0.00    0.633       0.444
# 72                       1.0          0.00    0.793       0.806
# 73                       0.0          0.66    0.791       0.822
# 74                       0.0          0.00    0.801       0.093
# 75                       1.0          0.00    0.715       0.438
# 76                       0.0          0.00    0.340       0.108
# 77                       0.0          0.00    0.737       0.039
# 78                       1.0          0.00    0.690       0.275
# 79                       0.0          0.00    0.831       0.314
# 80                       1.0          0.00    0.763       0.758
# 81                       1.0          0.00    0.588       0.098
# 82                       1.0          0.00    0.821       0.759
# 83                       0.0          0.00    0.633       0.628
# 84                       0.5          0.00    0.452       0.189
# 85                       0.0          0.66    0.825       0.815
# 86                       0.0          0.66    0.904       0.880
# 87                       0.0          0.66    0.887       0.839
# 88                       1.0          0.00    0.560       0.084
# 89                       0.0          0.00    0.653       0.401
# 90                       0.0          0.33    0.712       0.650
# 91                       0.5          0.00    0.658       0.096
# 92                       0.0          0.00    0.670       0.445
# 93                       0.5          0.00    0.394       0.245
# 94                       1.0          0.00    0.700       0.237
# 95                       1.0          0.00    0.675       0.355
# 96                       0.5          0.00    0.633       0.153
# 97                       0.0          1.00    0.862       0.797
# 98                       0.5          0.00    0.398       0.407
# 99                       0.0          1.00    0.891       0.810
# 100                      0.5          0.00    0.296       0.328
# 101                      0.0          0.33    0.753       0.801
# 102                      1.0          0.00    0.607       0.035
# 103                      0.5          0.33    0.684       0.312
# 104                      0.0          0.00    0.450       0.138
# 105                      0.5          0.00    0.418       0.388
#
#      freedom_socialism  freedom_family  freedom_ethnicity  freedom_gender  \
# 0                -0.05            0.07               0.06            0.11
# 1                -0.15            0.04              -0.00            0.03
# 2                -0.01            0.05               0.03            0.04
# 3                -0.04            0.28               0.18            0.22
# 4                 0.12            0.35               0.23            0.29
# 5                 0.17            0.30               0.28            0.27
# 6                 0.00            0.02              -0.02            0.05
# 7                 0.00            0.13               0.08            0.04
# 8                  NaN             NaN                NaN             NaN
# 9                -0.12            0.11               0.03            0.18
# 10               -0.06            0.12               0.08            0.14
# 11               -0.02            0.22               0.13            0.18
# 12               -0.08            0.13              -0.03            0.10
# 13               -0.20            0.01               0.18            0.30
# 14               -0.17            0.20              -0.01            0.10
# 15               -0.02            0.33               0.22            0.27
# 16                0.08            0.20               0.09            0.15
# 17               -0.07            0.12               0.09            0.10
# 18               -0.02            0.25               0.02            0.12
# 19               -0.16            0.41               0.17            0.13
# 20               -0.00            0.21               0.06            0.14
# 21               -0.06            0.14               0.07            0.18
# 22                0.20            0.26               0.23            0.26
# 23               -0.00            0.16              -0.02            0.21
# 24               -0.02            0.06              -0.03            0.15
# 25               -0.06            0.14                NaN            0.15
# 26               -0.02            0.14               0.05            0.20
# 27               -0.07            0.21              -0.03            0.20
# 28                0.09            0.33               0.27            0.31
# 29                0.09            0.35               0.31            0.30
# 30               -0.08            0.09               0.04            0.13
# 31                0.07            0.36               0.28            0.32
# 32                0.02           -0.02               0.02            0.05
# 33                0.11            0.25               0.29            0.23
# 34               -0.04            0.08              -0.13            0.01
# 35               -0.02            0.02              -0.01           -0.00
# 36               -0.15            0.21               0.06            0.26
# 37               -0.05            0.24               0.06            0.21
# 38                0.10            0.27               0.22            0.22
# 39                0.08            0.06               0.04            0.09
# 40               -0.03           -0.05              -0.00            0.15
# 41               -0.07            0.17               0.04            0.13
# 42               -0.19            0.15              -0.03            0.17
# 43                 NaN             NaN                NaN             NaN
# 44                 NaN             NaN                NaN             NaN
# 45                0.00            0.23               0.24            0.30
# 46               -0.09            0.23               0.18            0.31
# 47               -0.04            0.06               0.03            0.01
# 48                0.03            0.10               0.02            0.11
# 49               -0.06            0.09              -0.05            0.00
# 50               -0.11            0.21               0.15            0.28
# 51                 NaN             NaN                NaN             NaN
# 52               -0.07            0.12               0.08            0.14
# 53               -0.03            0.16               0.02            0.17
# 54               -0.07            0.03              -0.02            0.09
# 55                0.02            0.14               0.04            0.11
# 56                 NaN             NaN                NaN             NaN
# 57               -0.04            0.00               0.04            0.10
# 58                0.01           -0.00               0.11            0.12
# 59                0.10           -0.14               0.04            0.08
# 60                 NaN             NaN                NaN             NaN
# 61               -0.05            0.12               0.01            0.09
# 62               -0.07            0.02               0.01            0.06
# 63               -0.06            0.12              -0.01            0.15
# 64               -0.06            0.08               0.06            0.20
# 65                0.13            0.30               0.26            0.28
# 66                0.06            0.32               0.19            0.28
# 67               -0.08            0.09               0.03            0.08
# 68                0.11            0.37               0.27            0.29
# 69                0.05            0.01              -0.05            0.05
# 70               -0.04            0.08               0.03            0.05
# 71               -0.03            0.04              -0.01            0.07
# 72               -0.11            0.28               0.14            0.22
# 73               -0.06            0.27               0.08            0.17
# 74                 NaN             NaN                NaN             NaN
# 75               -0.08            0.20               0.06            0.15
# 76               -0.03            0.12               0.12            0.00
# 77                 NaN             NaN                NaN             NaN
# 78               -0.13            0.17               0.15            0.17
# 79               -0.07            0.23               0.08            0.18
# 80               -0.08            0.18               0.02            0.18
# 81                0.03           -0.20               0.19            0.17
# 82               -0.02            0.25               0.15            0.23
# 83                0.03            0.12               0.01            0.05
# 84               -0.04            0.02              -0.00            0.04
# 85                0.03            0.33               0.20            0.25
# 86                0.06            0.35               0.22            0.27
# 87                0.12            0.37               0.23            0.34
# 88               -0.06             NaN              -0.16            0.19
# 89               -0.01            0.12               0.08            0.19
# 90               -0.01            0.08               0.05            0.11
# 91               -0.04            0.09               0.02            0.09
# 92               -0.02            0.20               0.22            0.29
# 93                0.04            0.14              -0.12            0.12
# 94               -0.04            0.13              -0.04            0.08
# 95                0.01            0.27               0.13            0.26
# 96               -0.02             NaN                NaN            0.07
# 97                0.10            0.33               0.26            0.29
# 98               -0.05            0.03               0.03            0.04
# 99               -0.02            0.38               0.17            0.28
# 100              -0.00            0.05              -0.03            0.04
# 101               0.01            0.27               0.14            0.14
# 102              -0.02           -0.04              -0.03            0.09
# 103              -0.01            0.08               0.01            0.09
# 104               0.10            0.21               0.01            0.20
# 105               0.07            0.08               0.02            0.02
#
#      freedom_nationalism  freedom_religiosity  socialism_family  \
# 0                  -0.04                -0.07             -0.11
# 1                  -0.11                -0.05              0.05
# 2                  -0.06                -0.08             -0.02
# 3                  -0.19                -0.14              0.05
# 4                  -0.21                -0.16              0.05
# 5                  -0.19                -0.19              0.04
# 6                   0.00                -0.19              0.15
# 7                  -0.12                -0.10             -0.05
# 8                    NaN                  NaN              0.02
# 9                  -0.10                -0.13             -0.05
# 10                 -0.16                -0.15             -0.08
# 11                 -0.20                -0.15             -0.05
# 12                 -0.04                -0.10             -0.13
# 13                  0.03                -0.06             -0.01
# 14                 -0.17                -0.11             -0.12
# 15                 -0.14                -0.21              0.08
# 16                 -0.10                -0.14              0.10
# 17                 -0.07                -0.05             -0.05
# 18                 -0.17                -0.16             -0.02
# 19                 -0.16                -0.26             -0.15
# 20                 -0.10                -0.18             -0.11
# 21                  0.01                -0.11             -0.13
# 22                 -0.17                -0.06              0.03
# 23                 -0.11                -0.22             -0.06
# 24                 -0.06                -0.08              0.03
# 25                 -0.10                -0.15             -0.10
# 26                 -0.07                -0.16             -0.02
# 27                  0.04                -0.16             -0.08
# 28                 -0.07                -0.11              0.02
# 29                 -0.18                -0.09              0.07
# 30                 -0.03                -0.01             -0.00
# 31                 -0.23                -0.10              0.03
# 32                 -0.00                -0.09             -0.03
# 33                 -0.02                -0.35             -0.07
# 34                 -0.12                -0.15              0.08
# 35                  0.03                 0.02              0.02
# 36                 -0.03                -0.01             -0.05
# 37                 -0.04                -0.11             -0.05
# 38                 -0.22                -0.16              0.02
# 39                 -0.04                -0.03              0.00
# 40                  0.03                -0.03              0.05
# 41                 -0.16                -0.19             -0.05
# 42                 -0.21                -0.13              0.06
# 43                   NaN                  NaN              0.05
# 44                   NaN                  NaN               NaN
# 45                 -0.11                -0.16             -0.02
# 46                 -0.14                -0.07             -0.11
# 47                 -0.04                -0.07             -0.04
# 48                 -0.07                -0.14              0.00
# 49                 -0.06                -0.16              0.07
# 50                 -0.06                -0.13             -0.04
# 51                   NaN                  NaN               NaN
# 52                 -0.07                -0.15             -0.01
# 53                 -0.00                -0.13             -0.08
# 54                 -0.10                -0.16              0.07
# 55                 -0.07                -0.15              0.03
# 56                   NaN                  NaN             -0.01
# 57                 -0.11                -0.18              0.03
# 58                 -0.06                -0.15              0.05
# 59                  0.04                 0.00             -0.01
# 60                   NaN                  NaN             -0.07
# 61                 -0.10                -0.12              0.01
# 62                 -0.04                -0.03              0.08
# 63                 -0.11                -0.14             -0.08
# 64                 -0.10                -0.16             -0.02
# 65                 -0.12                -0.27              0.06
# 66                 -0.11                -0.18             -0.04
# 67                 -0.14                -0.14             -0.06
# 68                 -0.10                -0.17              0.03
# 69                 -0.05                -0.13              0.08
# 70                 -0.05                -0.09             -0.04
# 71                 -0.01                -0.09              0.04
# 72                 -0.08                -0.25             -0.07
# 73                  0.06                -0.15             -0.07
# 74                   NaN                  NaN             -0.02
# 75                 -0.07                -0.22             -0.11
# 76                  0.00                -0.06              0.05
# 77                   NaN                  NaN               NaN
# 78                 -0.19                -0.13             -0.10
# 79                 -0.08                -0.09             -0.03
# 80                 -0.05                -0.16             -0.07
# 81                 -0.03                -0.02             -0.14
# 82                 -0.11                -0.12             -0.06
# 83                 -0.08                -0.17              0.11
# 84                 -0.03                -0.12              0.05
# 85                 -0.21                -0.22              0.00
# 86                 -0.09                -0.08             -0.02
# 87                 -0.30                -0.16             -0.00
# 88                  0.10                -0.06               NaN
# 89                 -0.11                -0.15             -0.05
# 90                 -0.04                -0.07              0.01
# 91                 -0.01                -0.09              0.17
# 92                 -0.22                -0.25              0.00
# 93                 -0.04                -0.03              0.04
# 94                 -0.04                -0.10             -0.04
# 95                 -0.20                -0.15             -0.09
# 96                 -0.04                -0.08               NaN
# 97                 -0.19                -0.14             -0.00
# 98                 -0.06                -0.11              0.01
# 99                 -0.19                -0.23              0.01
# 100                -0.13                -0.15             -0.18
# 101                -0.18                -0.10             -0.02
# 102                 0.04                 0.03             -0.04
# 103                -0.02                -0.04             -0.03
# 104                -0.22                -0.29              0.12
# 105                -0.25                -0.19              0.24
#
#      socialism_ethnicity  socialism_gender  socialism_nationalism  \
# 0                  -0.05              0.05                   0.05
# 1                    NaN              0.02                  -0.06
# 2                  -0.09             -0.01                  -0.10
# 3                   0.02             -0.01                  -0.01
# 4                   0.02              0.03                  -0.09
# 5                  -0.02              0.00                  -0.07
# 6                  -0.00             -0.03                  -0.13
# 7                  -0.06             -0.03                  -0.07
# 8                   0.05               NaN                  -0.06
# 9                  -0.02              0.00                   0.03
# 10                 -0.21              0.01                  -0.12
# 11                 -0.03             -0.06                  -0.00
# 12                 -0.10             -0.12                  -0.01
# 13                 -0.12             -0.12                  -0.04
# 14                 -0.08             -0.02                   0.05
# 15                 -0.03             -0.07                  -0.11
# 16                  0.01             -0.03                  -0.09
# 17                 -0.04             -0.04                   0.01
# 18                  0.04             -0.03                   0.03
# 19                 -0.06              0.12                  -0.04
# 20                 -0.03             -0.08                  -0.05
# 21                 -0.07             -0.08                  -0.08
# 22                  0.05              0.05                  -0.13
# 23                 -0.01             -0.03                   0.11
# 24                 -0.01             -0.04                  -0.00
# 25                   NaN             -0.05                   0.02
# 26                 -0.02             -0.07                   0.00
# 27                 -0.08             -0.02                  -0.16
# 28                  0.02              0.01                  -0.09
# 29                  0.10              0.03                  -0.05
# 30                 -0.01             -0.07                  -0.10
# 31                  0.05              0.05                  -0.13
# 32                  0.07              0.00                  -0.01
# 33                  0.09             -0.01                  -0.10
# 34                 -0.08             -0.08                  -0.01
# 35                 -0.01              0.02                  -0.02
# 36                 -0.03             -0.09                  -0.01
# 37                 -0.01             -0.04                  -0.09
# 38                  0.05              0.05                  -0.13
# 39                 -0.02              0.01                  -0.04
# 40                  0.03             -0.04                   0.04
# 41                 -0.04             -0.05                   0.04
# 42                  0.06             -0.01                   0.07
# 43                 -0.08               NaN                  -0.06
# 44                   NaN               NaN                    NaN
# 45                  0.02             -0.06                  -0.11
# 46                 -0.02             -0.07                  -0.06
# 47                 -0.04             -0.01                  -0.06
# 48                 -0.05             -0.00                  -0.02
# 49                  0.06             -0.03                  -0.00
# 50                 -0.06             -0.08                  -0.06
# 51                  0.00              0.07                   0.08
# 52                 -0.02             -0.07                   0.01
# 53                 -0.04             -0.04                  -0.18
# 54                  0.04             -0.04                   0.03
# 55                 -0.12              0.03                  -0.20
# 56                 -0.04               NaN                    NaN
# 57                  0.01             -0.03                   0.04
# 58                  0.03              0.13                  -0.07
# 59                 -0.13             -0.13                   0.02
# 60                 -0.04               NaN                  -0.18
# 61                  0.01             -0.04                  -0.03
# 62                 -0.05             -0.10                  -0.12
# 63                 -0.06             -0.03                  -0.05
# 64                  0.01              0.07                  -0.09
# 65                  0.05              0.03                  -0.13
# 66                  0.00             -0.01                  -0.07
# 67                 -0.02             -0.06                   0.08
# 68                  0.05              0.01                  -0.10
# 69                  0.04              0.14                  -0.21
# 70                  0.01             -0.09                  -0.01
# 71                 -0.02              0.01                   0.01
# 72                 -0.10             -0.13                  -0.08
# 73                 -0.02             -0.01                  -0.08
# 74                  0.10             -0.05                   0.02
# 75                 -0.01             -0.08                  -0.04
# 76                 -0.08             -0.03                   0.02
# 77                   NaN               NaN                    NaN
# 78                 -0.04             -0.08                   0.02
# 79                  0.02             -0.08                  -0.08
# 80                 -0.03             -0.07                  -0.10
# 81                  0.05             -0.06                   0.05
# 82                 -0.02              0.01                  -0.09
# 83                  0.01             -0.12                  -0.03
# 84                  0.06             -0.04                   0.02
# 85                  0.05             -0.03                  -0.06
# 86                 -0.00             -0.01                  -0.11
# 87                  0.04              0.08                  -0.12
# 88                 -0.05             -0.13                  -0.08
# 89                  0.03              0.02                  -0.02
# 90                  0.05              0.01                   0.00
# 91                 -0.05              0.03                  -0.01
# 92                 -0.08             -0.09                  -0.10
# 93                 -0.00              0.11                  -0.12
# 94                 -0.07             -0.02                  -0.06
# 95                 -0.07             -0.08                  -0.10
# 96                  0.01             -0.11                  -0.07
# 97                  0.00             -0.00                  -0.12
# 98                 -0.09              0.03                  -0.03
# 99                  0.00             -0.01                  -0.12
# 100                -0.11              0.01                  -0.03
# 101                 0.00             -0.02                  -0.04
# 102                 0.12             -0.01                   0.02
# 103                 0.00             -0.00                  -0.02
# 104                 0.01              0.05                  -0.08
# 105                -0.03             -0.12                  -0.13
#
#      socialism_religiosity  family_ethnicity  family_gender  \
# 0                     0.05              0.12           0.01
# 1                    -0.17              0.11           0.03
# 2                    -0.01              0.14           0.15
# 3                     0.01              0.12           0.24
# 4                     0.02              0.16           0.45
# 5                     0.03              0.20           0.35
# 6                    -0.11              0.10          -0.02
# 7                     0.01              0.16           0.05
# 8                    -0.04              0.19            NaN
# 9                     0.07              0.06           0.10
# 10                    0.08              0.12           0.14
# 11                    0.00              0.11           0.21
# 12                    0.07              0.13           0.11
# 13                   -0.04              0.06           0.08
# 14                    0.07              0.06           0.09
# 15                   -0.03              0.14           0.35
# 16                   -0.01              0.13           0.21
# 17                    0.02              0.09           0.06
# 18                    0.04              0.05           0.20
# 19                    0.11              0.19           0.27
# 20                    0.05              0.07           0.24
# 21                    0.07              0.07           0.21
# 22                    0.01              0.22           0.41
# 23                    0.13              0.08           0.20
# 24                    0.01              0.05           0.05
# 25                   -0.01               NaN           0.03
# 26                   -0.07             -0.27           0.03
# 27                    0.10              0.09           0.19
# 28                    0.02              0.25           0.39
# 29                   -0.02              0.24           0.33
# 30                   -0.07              0.12           0.06
# 31                    0.01              0.23           0.36
# 32                   -0.02             -0.02          -0.04
# 33                   -0.04              0.22           0.25
# 34                    0.03             -0.04          -0.01
# 35                   -0.02             -0.04           0.03
# 36                    0.10              0.16           0.17
# 37                    0.05              0.09           0.24
# 38                    0.02              0.38           0.41
# 39                   -0.01             -0.01           0.00
# 40                   -0.01              0.01          -0.04
# 41                    0.08              0.06           0.13
# 42                    0.01             -0.10           0.06
# 43                   -0.02              0.16            NaN
# 44                     NaN               NaN            NaN
# 45                    0.03              0.19           0.37
# 46                    0.01              0.13           0.32
# 47                   -0.10              0.05           0.09
# 48                   -0.08              0.11           0.07
# 49                   -0.05             -0.03          -0.05
# 50                   -0.01              0.15           0.26
# 51                     NaN               NaN            NaN
# 52                    0.04              0.14           0.15
# 53                    0.01              0.10           0.22
# 54                   -0.08              0.06           0.07
# 55                    0.05              0.10           0.15
# 56                    0.04              0.14            NaN
# 57                    0.05              0.09           0.03
# 58                   -0.03              0.15           0.25
# 59                   -0.05             -0.10          -0.03
# 60                   -0.02              0.06            NaN
# 61                    0.00              0.06           0.15
# 62                    0.15             -0.13           0.05
# 63                    0.08              0.09           0.11
# 64                    0.04             -0.11           0.08
# 65                   -0.05              0.13           0.38
# 66                    0.01              0.14           0.42
# 67                    0.03             -0.05           0.10
# 68                   -0.02              0.31           0.40
# 69                   -0.03              0.02           0.03
# 70                    0.02              0.03           0.06
# 71                   -0.02              0.03          -0.00
# 72                    0.05              0.17           0.26
# 73                    0.07              0.14           0.37
# 74                     NaN              0.03          -0.04
# 75                    0.12              0.10           0.16
# 76                    0.03             -0.11           0.01
# 77                     NaN              0.05           0.11
# 78                    0.10              0.10           0.19
# 79                   -0.04              0.06           0.27
# 80                    0.04              0.08           0.22
# 81                    0.06             -0.15          -0.01
# 82                    0.10              0.22           0.38
# 83                   -0.09              0.02          -0.06
# 84                   -0.05              0.04           0.02
# 85                   -0.02              0.22           0.36
# 86                    0.03              0.27           0.30
# 87                    0.05              0.15           0.38
# 88                   -0.00               NaN            NaN
# 89                   -0.02              0.08           0.11
# 90                   -0.04              0.04           0.14
# 91                    0.00              0.10           0.16
# 92                    0.01              0.16           0.18
# 93                    0.02             -0.10           0.18
# 94                   -0.01              0.06           0.08
# 95                    0.13              0.12           0.32
# 96                   -0.06             -0.01           0.01
# 97                    0.02              0.23           0.40
# 98                   -0.04              0.02           0.01
# 99                   -0.03              0.11           0.36
# 100                  -0.04             -0.01          -0.01
# 101                   0.00              0.21           0.29
# 102                  -0.05             -0.03           0.11
# 103                  -0.03              0.10           0.07
# 104                  -0.15             -0.03           0.05
# 105                   0.01             -0.07          -0.03
#
#      family_nationalism  family_religiosity  ethnicity_gender  \
# 0                 -0.22               -0.17              0.22
# 1                 -0.09               -0.10              0.18
# 2                 -0.04               -0.17              0.02
# 3                 -0.14               -0.32              0.20
# 4                 -0.19               -0.43              0.24
# 5                 -0.13               -0.42              0.26
# 6                 -0.02               -0.02              0.10
# 7                 -0.16               -0.22              0.13
# 8                 -0.13               -0.36               NaN
# 9                 -0.06               -0.19              0.10
# 10                -0.13               -0.18              0.15
# 11                -0.11               -0.21              0.16
# 12                -0.13               -0.14              0.01
# 13                -0.01               -0.05              0.22
# 14                -0.18               -0.19              0.07
# 15                -0.19               -0.44              0.31
# 16                -0.20               -0.28              0.20
# 17                -0.04               -0.06              0.20
# 18                -0.12               -0.19              0.11
# 19                -0.27               -0.41              0.14
# 20                -0.03               -0.32              0.17
# 21                -0.11               -0.33              0.15
# 22                -0.02               -0.37              0.29
# 23                -0.16               -0.28             -0.02
# 24                -0.01               -0.12              0.05
# 25                -0.03               -0.16               NaN
# 26                -0.08               -0.07              0.22
# 27                -0.07               -0.22              0.03
# 28                -0.03               -0.39              0.31
# 29                -0.06               -0.33              0.30
# 30                -0.15               -0.19              0.08
# 31                -0.12               -0.36              0.30
# 32                 0.01               -0.09              0.08
# 33                -0.03               -0.41              0.24
# 34                 0.01               -0.10              0.11
# 35                 0.01                0.03             -0.02
# 36                -0.06               -0.20              0.19
# 37                -0.15               -0.26              0.10
# 38                -0.22               -0.34              0.35
# 39                -0.07               -0.20              0.12
# 40                -0.10               -0.11             -0.01
# 41                -0.17               -0.27              0.06
# 42                -0.13               -0.19             -0.01
# 43                -0.07               -0.43               NaN
# 44                 0.13                 NaN               NaN
# 45                -0.10               -0.43              0.31
# 46                -0.14               -0.17              0.31
# 47                -0.07               -0.11              0.16
# 48                -0.04               -0.10              0.16
# 49                -0.13               -0.09              0.15
# 50                -0.17               -0.25              0.21
# 51                  NaN                 NaN              0.19
# 52                -0.13               -0.15              0.23
# 53                -0.12               -0.26              0.01
# 54                 0.01               -0.08              0.18
# 55                -0.15               -0.31              0.06
# 56                -0.15               -0.32               NaN
# 57                -0.18               -0.19              0.14
# 58                -0.25               -0.05              0.30
# 59                 0.06               -0.11              0.15
# 60                -0.12               -0.34               NaN
# 61                -0.06               -0.17              0.21
# ...
# 64                 0.09               -0.07              0.09
# 65                -0.06               -0.51              0.25
# 66                -0.08               -0.48              0.24
# 67                -0.03               -0.18              0.11
# 68                 0.01               -0.42              0.32
# 69                -0.18               -0.06              0.14
# 70                -0.06               -0.13              0.12
# 71                 0.00               -0.05              0.11
# 72                -0.12               -0.41              0.30
# 73                 0.02               -0.30              0.26
# 74                -0.04                 NaN              0.10
# 75                -0.09               -0.28              0.23
# 76                 0.01               -0.05              0.06
# 77                  NaN               -0.05              0.17
# 78                -0.11               -0.16              0.17
# 79                -0.07               -0.23              0.17
# 80                -0.07               -0.35              0.09
# 81                -0.07               -0.13              0.16
# 82                -0.16               -0.35              0.24
# 83                -0.05               -0.19              0.14
# 84                -0.02               -0.12              0.12
# 85                -0.24               -0.38              0.25
# 86                -0.01               -0.30              0.27
# 87                -0.19               -0.40              0.27
# 88                  NaN                 NaN              0.22
# 89                -0.10               -0.20              0.28
# 90                -0.04               -0.08              0.16
# 91                 0.03                0.00              0.23
# 92                -0.16               -0.23              0.30
# 93                -0.15                0.02              0.03
# 94                -0.05               -0.25              0.06
# 95                -0.04               -0.31              0.21
# 96                  NaN               -0.05              0.06
# 97                -0.12               -0.39              0.30
# 98                -0.08               -0.12              0.13
# 99                -0.22               -0.45              0.27
# 100               -0.05               -0.10              0.17
# 101               -0.14               -0.29              0.25
# 102                0.01                0.08              0.04
# 103               -0.15               -0.18              0.12
# 104               -0.05               -0.19              0.24
# 105               -0.00               -0.06              0.13
#
#      ethnicity_nationalism  ethnicity_religiosity  gender_nationalism  \
# 0                    -0.02                  -0.05                0.11
# 1                      NaN                  -0.01               -0.03
# 2                     0.12                  -0.02               -0.07
# 3                    -0.11                  -0.08               -0.09
# 4                    -0.08                   0.03               -0.19
# 5                    -0.12                  -0.03               -0.10
# 6                    -0.03                   0.05                0.06
# 7                    -0.01                  -0.09                0.01
# 8                    -0.04                   0.02                 NaN
# 9                    -0.06                  -0.04               -0.05
# 10                    0.10                  -0.08               -0.15
# 11                   -0.08                  -0.07               -0.13
# 12                   -0.04                  -0.02                0.05
# 13                   -0.02                  -0.00               -0.04
# 14                    0.03                  -0.00               -0.04
# 15                    0.01                  -0.03               -0.13
# 16                   -0.04                  -0.04               -0.09
# 17                    0.01                  -0.02                0.04
# 18                   -0.04                  -0.03               -0.10
# 19                   -0.09                  -0.07               -0.17
# 20                    0.01                  -0.10               -0.03
# 21                    0.07                  -0.05                0.04
# 22                   -0.10                  -0.06               -0.07
# 23                   -0.02                   0.02               -0.05
# 24                    0.05                  -0.07               -0.01
# 25                     NaN                    NaN               -0.02
# 26                    0.02                  -0.15               -0.05
# 27                   -0.02                   0.05                0.07
# 28                   -0.04                   0.01                0.06
# 29                   -0.09                   0.00               -0.02
# 30                   -0.06                  -0.02                0.02
# 31                   -0.11                   0.02               -0.11
# 32                   -0.05                  -0.01               -0.02
# 33                   -0.05                  -0.22                0.02
# 34                    0.00                  -0.00                0.02
# 35                    0.03                  -0.05               -0.10
# 36                    0.03                   0.03               -0.02
# 37                    0.01                  -0.05               -0.04
# 38                   -0.15                  -0.14               -0.13
# 39                   -0.05                  -0.04                0.04
# 40                    0.08                   0.01               -0.02
# 41                   -0.03                  -0.05               -0.12
# 42                   -0.02                    NaN               -0.07
# 43                   -0.08                  -0.05                 NaN
# 44                     NaN                    NaN                 NaN
# 45                   -0.06                  -0.05               -0.01
# 46                   -0.07                  -0.01               -0.21
# 47                   -0.08                  -0.03               -0.05
# 48                    0.04                   0.00               -0.04
# 49                    0.11                   0.01                0.06
# 50                   -0.01                   0.07               -0.08
# 51                    0.04                    NaN               -0.12
# 52                   -0.07                  -0.07               -0.15
# 53                   -0.19                   0.00                0.01
# 54                    0.01                   0.04               -0.08
# 55                    0.08                  -0.06               -0.04
# 56                   -0.11                   0.01                 NaN
# 57                   -0.10                  -0.06               -0.13
# 58                   -0.19                  -0.12               -0.14
# 59                   -0.09                   0.01               -0.07
# 60                   -0.08                  -0.03                 NaN
# 61                   -0.03                  -0.03                0.01
# 62                    0.06                  -0.13                0.05
# 63                   -0.01                  -0.07               -0.11
# 64                   -0.02                  -0.13               -0.13
# 65                   -0.02                  -0.03               -0.04
# 66                   -0.01                   0.05               -0.09
# 67                    0.05                  -0.08                0.01
# 68                   -0.04                  -0.01                0.01
# 69                   -0.03                   0.02               -0.20
# 70                   -0.02                   0.03               -0.05
# 71                    0.00                  -0.01               -0.02
# 72                   -0.01                  -0.11               -0.02
# 73                   -0.03                  -0.01                0.06
# 74                   -0.05                    NaN                0.01
# 75                   -0.06                  -0.06               -0.04
# 76                   -0.13                  -0.10                0.17
# 77                     NaN                  -0.08                 NaN
# 78                   -0.09                  -0.05               -0.08
# 79                    0.07                   0.02                0.06
# 80                    0.10                  -0.03               -0.03
# 81                   -0.04                   0.06                0.01
# 82                   -0.09                  -0.07               -0.10
# 83                    0.01                   0.01               -0.05
# 84                    0.00                  -0.03               -0.04
# 85                   -0.11                  -0.08               -0.16
# 86                   -0.02                   0.05                0.00
# 87                   -0.19                  -0.00               -0.23
# 88                    0.07                  -0.06                0.14
# 89                   -0.10                  -0.09               -0.04
# 90                   -0.02                  -0.03               -0.05
# 91                    0.04                  -0.06                0.06
# 92                   -0.10                  -0.17               -0.05
# 93                    0.09                  -0.01               -0.26
# 94                   -0.04                  -0.04               -0.05
# 95                   -0.04                  -0.06               -0.09
# 96                    0.11                  -0.01               -0.00
# 97                   -0.08                   0.06               -0.08
# 98                    0.03                   0.02                0.10
# 99                   -0.05                  -0.01               -0.16
# 100                  -0.04                   0.01               -0.04
# 101                  -0.13                  -0.06               -0.08
# 102                  -0.04                   0.01               -0.06
# 103                  -0.09                  -0.05               -0.02
# 104                  -0.13                  -0.14               -0.10
# 105                   0.07                   0.03                0.03
#
#      gender_religiosity  nationalism_religiosity
# 0                 -0.10                    -0.00
# 1                 -0.10                     0.15
# 2                 -0.10                     0.10
# 3                 -0.10                     0.17
# 4                 -0.16                     0.00
# 5                 -0.12                     0.05
# 6                 -0.05                     0.05
# 7                  0.06                     0.14
# 8                   NaN                     0.06
# 9                 -0.03                     0.06
# 10                -0.01                     0.09
# 11                -0.02                     0.10
# 12                -0.06                    -0.01
# 13                 0.02                     0.09
# 14                 0.00                     0.02
# 15                -0.18                     0.12
# 16                -0.06                     0.14
# 17                -0.07                    -0.02
# 18                -0.00                     0.09
# 19                -0.12                     0.17
# 20                -0.06                     0.08
# 21                -0.12                     0.00
# 22                -0.14                     0.08
# 23                -0.10                     0.12
# 24                -0.04                     0.01
# 25                 0.13                    -0.01
# 26                -0.13                     0.04
# 27                -0.06                    -0.11
# 28                -0.13                     0.04
# 29                -0.16                    -0.01
# 30                 0.10                     0.11
# 31                -0.16                     0.03
# 32                 0.04                     0.05
# 33                -0.27                     0.05
# 34                 0.09                     0.06
# 35                -0.02                     0.01
# 36                -0.01                     0.04
# 37                -0.08                    -0.03
# 38                -0.09                     0.14
# 39                -0.05                     0.05
# 40                 0.06                     0.14
# 41                -0.14                     0.25
# 42                -0.13                     0.05
# 43                  NaN                     0.08
# 44                  NaN                      NaN
# 45                -0.12                     0.11
# 46                -0.13                     0.18
# 47                -0.08                     0.05
# 48                -0.14                     0.11
# 49                 0.16                     0.12
# 50                 0.01                     0.09
# 51                  NaN                      NaN
# 52                -0.20                     0.09
# 53                -0.07                    -0.04
# 54                -0.09                     0.15
# 55                -0.05                     0.04
# 56                  NaN                    -0.01
# 57                -0.10                     0.25
# 58                -0.10                     0.14
# 59                 0.05                     0.02
# 60                  NaN                     0.13
# 61                -0.04                     0.06
# 62                -0.16                    -0.09
# 63                -0.05                     0.04
# 64                -0.07                     0.10
# 65                -0.23                     0.06
# 66                -0.12                    -0.03
# 67                -0.02                    -0.00
# 68                -0.22                    -0.05
# 69                 0.06                     0.16
# 70                 0.02                     0.05
# 71                -0.00                     0.03
# 72                -0.17                     0.13
# 73                -0.11                    -0.07
# 74                  NaN                      NaN
# 75                -0.09                     0.02
# 76                 0.04                     0.08
# 77                -0.04                      NaN
# 78                -0.07                     0.06
# 79                -0.09                     0.09
# 80                -0.05                     0.01
# 81                -0.09                    -0.05
# 82                -0.14                     0.07
# 83                 0.07                     0.07
# 84                 0.05                    -0.02
# 85                -0.20                     0.14
# 86                -0.07                    -0.04
# 87                -0.13                     0.08
# 88                -0.13                     0.03
# 89                -0.14                     0.12
# 90                -0.02                     0.03
# 91                -0.16                     0.12
# 92                -0.25                     0.24
# 93                 0.12                    -0.02
# 94                -0.01                     0.12
# 95                -0.16                    -0.11
# 96                -0.05                     0.16
# 97                -0.18                    -0.00
# 98                 0.07                     0.08
# 99                -0.12                     0.13
# 100                0.02                     0.10
# 101               -0.02                     0.06
# 102               -0.07                    -0.03
# 103                0.01                     0.08
# 104               -0.29                     0.17
# 105                0.16                     0.22

# %% [markdown]
# ## The saving_merged_data() method

# %%
country_data = pd.read_csv('./country_level_processed_data/predictors_correlations.csv')

# %%
country_data
# Out:
#      Unnamed: 0  iso_numeric iso_alpha_2 iso_alpha3            country_name  \
# 0             0            8          AL        ALB                 Albania
# 1             1           12          DZ        DZA                 Algeria
# 2             2           31          AZ        AZE              Azerbaijan
# 3             3           32          AR        ARG               Argentina
# 4             4           36          AU        AUS               Australia
# 5             5           40          AT        AUT                 Austria
# 6             6           50          BD        BGD              Bangladesh
# 7             7           51          AM        ARM                 Armenia
# 8             8           56          BE        BEL                 Belgium
# 9             9           68          BO        BOL                 Bolivia
# 10           10           70          BA        BIH  Bosnia and Herzegovina
# 11           11           76          BR        BRA                  Brazil
# 12           12          100          BR        BGR                Bulgaria
# 13           13          104          MM        MMR                 Myanmar
# 14           14          112          BY        BLR                 Belarus
# 15           15          124          CA        CAN                  Canada
# 16           16          152          CL        CHL                   Chile
# 17           17          156          CN        CHN                   China
# 18           18          170          CO        COL                Colombia
# 19           19          191          HR        HRV                 Croatia
# 20           20          196          CY        CYP                  Cyprus
# 21           21          203          CZ        CZE          Czech Republic
# 22           22          208          DK        DNK                 Denmark
# 23           23          214          DO        DOM      Dominican Republic
# 24           24          218          EC        ECU                 Ecuador
# 25           25          222          SV        SLV             El Salvador
# 26           26          231          ET        ETH                Ethiopia
# 27           27          233          EE        EST                 Estonia
# 28           28          246          FI        FIN                 Finland
# 29           29          250          FR        FRA                  France
# 30           30          268          GE        GEO                 Georgia
# 31           31          276          DE        DEU                 Germany
# 32           32          288          GH        GHA                   Ghana
# 33           33          300          GR        GRC                  Greece
# 34           34          320          GT        GTM               Guatemala
# 35           35          332          HT        HTI                   Haiti
# 36           36          344          HK        HKG               Hong Kong
# 37           37          348          HU        HUN                 Hungary
# 38           38          352          IS        ISL                 Iceland
# 39           39          356          IN        IND                   India
# 40           40          360          ID        IDN               Indonesia
# 41           41          364          IR        IRN                    Iran
# 42           42          368          IQ        IRQ                    Iraq
# 43           43          372          IE        IRL                 Ireland
# 44           44          376          IL        ISR                  Israel
# 45           45          380          IT        ITA                   Italy
# 46           46          392          JP        JPN                   Japan
# 47           47          398          KZ        KAZ              Kazakhstan
# 48           48          400          JO        JOR                  Jordan
# 49           49          404          KE        KEN                   Kenya
# 50           50          410          KR        KOR             South Korea
# 51           51          414          KW        KWT                  Kuwait
# 52           52          417          KG        KGZ              Kyrgyzstan
# 53           53          428          LV        LVA                  Latvia
# 54           54          434          LY        LBY                   Libya
# 55           55          440          LT        LTU               Lithuania
# 56           56          442          LU        LUX              Luxembourg
# 57           57          458          MY        MYS                Malaysia
# 58           58          462          MV        MDV                Maldives
# 59           59          466          ML        MLI                    Mali
# 60           60          470          MT        MLT                   Malta
# 61           61          484          MX        MEX                  Mexico
# 62           62          496          MN        MNG                Mongolia
# 63           63          498          MD        MDA                 Moldova
# 64           64          504          MA        MAR                 Morocco
# 65           65          528          NL        NLD             Netherlands
# 66           66          554          NZ        NZL            New Zealand
# 67           67          558          NI        NIC               Nicaragua
# 68           68          578          NO        NOR                  Norway
# 69           69          586          PK        PAK                Pakistan
# 70           70          604          PE        PER                    Peru
# 71           71          608          PH        PHL             Philippines
# 72           72          616          PL        POL                  Poland
# 73           73          620          PT        PRT                Portugal
# 74           74          634          QA        QAT                   Qatar
# 75           75          642          RO        ROU                 Romania
# 76           76          646          RW        RWA                  Rwanda
# 77           77          682          SA        SAU            Saudi Arabia
# 78           78          688          RS        SRB                  Serbia
# 79           79          702          SG        SGP               Singapore
# 80           80          703          SK        SVK                Slovakia
# 81           81          704          VN        VNM                Vietnam
# 82           82          705          SI        SVN                Slovenia
# 83           83          710         ZA         ZAF            South Africa
# 84           84          716          ZW        ZWE                Zimbabwe
# 85           85          724          ES        ESP                   Spain
# 86           86          752          SE        SWE                  Sweden
# 87           87          756          CH        CHE             Switzerland
# 88           88          762          TJ        TJK              Tajikistan
# 89           89          764          TH        THA                Thailand
# 90           90          780          TT        TTO     Trinidad and Tobago
# 91           91          788          TN        TUN                 Tunisia
# 92           92          792          TR        TUR                  Turkey
# 93           93          800          UG        UGA                  Uganda
# 94           94          804          UA        UKR                 Ukraine
# 95           95          807          MK        MKD         North Macedonia
# 96           96          818          EG        EGY                   Egypt
# 97           97          826          GB        GBR          United Kingdom
# 98           98          834          TZ        TZA                Tanzania
# 99           99          840          US        USA           United States
# 100         100          854          BF        BFA            Burkina Faso
# 101         101          858          UY        URY                 Uruguay
# 102         102          860          UZ        UZB              Uzbekistan
# 103         103          862          VE        VEN               Venezuela
# 104         104          887          YE        YEM                   Yemen
# 105         105          894          ZM        ZMB                  Zambia
#
#      authoritarian_socialism  culture_zone  hdi2010  v2x_libdem  \
# 0                        1.0          0.00    0.677       0.341
# 1                        0.5          0.00    0.649       0.162
# 2                        1.0          0.00    0.622       0.084
# 3                        0.0          0.33    0.779       0.662
# 4                        0.0          1.00    0.896       0.849
# 5                        0.0          0.66    0.871       0.785
# 6                        0.0          0.00    0.485       0.281
# 7                        1.0          0.00    0.662       0.214
# 8                        0.0          0.66    0.887       0.819
# 9                        0.0          0.33    0.632       0.530
# 10                       1.0          0.00    0.667       0.421
# 11                       0.0          0.33    0.679       0.735
# 12                       1.0          0.00    0.725       0.630
# 13                       0.5          0.00    0.410       0.018
# 14                       1.0          0.00    0.712       0.111
# 15                       0.0          1.00    0.890       0.759
# 16                       0.0          0.33    0.763       0.816
# 17                       1.0          0.00    0.584       0.063
# 18                       0.0          0.33    0.666       0.423
# 19                       1.0          0.00    0.759       0.626
# 20                       0.0          0.00    0.797       0.671
# 21                       1.0          0.00    0.808       0.810
# 22                       0.0          0.66    0.889       0.881
# 23                       0.0          0.33    0.646       0.365
# 24                       0.0          0.33    0.687       0.466
# 25                       0.0          0.33    0.617       0.324
# 26                       1.0          0.00    0.287       0.111
# 27                       1.0          0.00    0.787       0.804
# 28                       1.0          0.66    0.891       0.828
# 29                       1.0          0.66    0.844       0.803
# 30                       1.0          0.00    0.702       0.208
# 31                       1.0          0.66    0.889       0.866
# 32                       0.5          0.00    0.507       0.573
# 33                       0.0          0.00    0.810       0.798
# 34                       0.0          0.33    0.550       0.376
# 35                       0.0          0.33    0.470       0.273
# 36                       0.0          0.00    0.851       0.317
# 37                       1.0          0.00    0.773       0.756
# 38                       0.0          0.66    0.871       0.789
# 39                       0.0          0.00    0.491       0.584
# 40                       0.0          0.00    0.595       0.511
# 41                       0.0          0.00    0.685       0.173
# 42                       0.5          0.00    0.589       0.068
# 43                       0.0          1.00    0.847       0.816
# 44                       0.0          0.00    0.844       0.696
# 45                       0.0          0.66    0.841       0.763
# 46                       0.0          0.00    0.877       0.762
# 47                       1.0          0.00    0.680       0.133
# 48                       0.0          0.00    0.678       0.132
# 49                       0.0          0.00    0.481       0.251
# 50                       0.0          0.00    0.825       0.771
# 51                       0.0          0.00    0.787       0.279
# 52                       1.0          0.00    0.621       0.164
# 53                       1.0          0.00    0.756       0.705
# 54                       0.5          0.00    0.712       0.050
# 55                       1.0          0.00    0.766       0.765
# 56                       0.0          0.66    0.864       0.796
# 57                       0.0          0.00    0.721       0.165
# 58                       0.0          0.00    0.628       0.059
# 59                       0.5          0.00    0.317       0.374
# 60                       0.0          0.66    0.779       0.616
# 61                       0.0          0.33    0.709       0.480
# 62                       1.0          0.00    0.598       0.559
# 63                       1.0          0.00    0.641       0.448
# 64                       0.0          0.00    0.521       0.217
# 65                       0.0          0.66    0.893       0.808
# 66                       0.0          1.00    0.887       0.834
# 67                       0.5          0.33    0.566       0.381
# 68                       0.0          1.00    0.913       0.858
# 69                       0.0          0.00    0.441       0.094
# 70                       0.0          0.33    0.676       0.195
# 71                       0.0          0.00    0.633       0.444
# 72                       1.0          0.00    0.793       0.806
# 73                       0.0          0.66    0.791       0.822
# 74                       0.0          0.00    0.801       0.093
# 75                       1.0          0.00    0.715       0.438
# 76                       0.0          0.00    0.340       0.108
# 77                       0.0          0.00    0.737       0.039
# 78                       1.0          0.00    0.690       0.275
# 79                       0.0          0.00    0.831       0.314
# 80                       1.0          0.00    0.763       0.758
# 81                       1.0          0.00    0.588       0.098
# 82                       1.0          0.00    0.821       0.759
# 83                       0.0          0.00    0.633       0.628
# 84                       0.5          0.00    0.452       0.189
# 85                       0.0          0.66    0.825       0.815
# 86                       0.0          0.66    0.904       0.880
# 87                       0.0          0.66    0.887       0.839
# 88                       1.0          0.00    0.560       0.084
# 89                       0.0          0.00    0.653       0.401
# 90                       0.0          0.33    0.712       0.650
# 91                       0.5          0.00    0.658       0.096
# 92                       0.0          0.00    0.670       0.445
# 93                       0.5          0.00    0.394       0.245
# 94                       1.0          0.00    0.700       0.237
# 95                       1.0          0.00    0.675       0.355
# 96                       0.5          0.00    0.633       0.153
# 97                       0.0          1.00    0.862       0.797
# 98                       0.5          0.00    0.398       0.407
# 99                       0.0          1.00    0.891       0.810
# 100                      0.5          0.00    0.296       0.328
# 101                      0.0          0.33    0.753       0.801
# 102                      1.0          0.00    0.607       0.035
# 103                      0.5          0.33    0.684       0.312
# 104                      0.0          0.00    0.450       0.138
# 105                      0.5          0.00    0.418       0.388
#
#      freedom_socialism  freedom_family  freedom_ethnicity  freedom_gender  \
# 0                -0.05            0.07               0.06            0.11
# 1                -0.15            0.04              -0.00            0.03
# 2                -0.01            0.05               0.03            0.04
# 3                -0.04            0.28               0.18            0.22
# 4                 0.12            0.35               0.23            0.29
# 5                 0.17            0.30               0.28            0.27
# 6                 0.00            0.02              -0.02            0.05
# 7                 0.00            0.13               0.08            0.04
# 8                  NaN             NaN                NaN             NaN
# 9                -0.12            0.11               0.03            0.18
# 10               -0.06            0.12               0.08            0.14
# 11               -0.02            0.22               0.13            0.18
# 12               -0.08            0.13              -0.03            0.10
# 13               -0.20            0.01               0.18            0.30
# 14               -0.17            0.20              -0.01            0.10
# 15               -0.02            0.33               0.22            0.27
# 16                0.08            0.20               0.09            0.15
# 17               -0.07            0.12               0.09            0.10
# 18               -0.02            0.25               0.02            0.12
# 19               -0.16            0.41               0.17            0.13
# 20               -0.00            0.21               0.06            0.14
# 21               -0.06            0.14               0.07            0.18
# 22                0.20            0.26               0.23            0.26
# 23               -0.00            0.16              -0.02            0.21
# 24               -0.02            0.06              -0.03            0.15
# 25               -0.06            0.14                NaN            0.15
# 26               -0.02            0.14               0.05            0.20
# 27               -0.07            0.21              -0.03            0.20
# 28                0.09            0.33               0.27            0.31
# 29                0.09            0.35               0.31            0.30
# 30               -0.08            0.09               0.04            0.13
# 31                0.07            0.36               0.28            0.32
# 32                0.02           -0.02               0.02            0.05
# 33                0.11            0.25               0.29            0.23
# 34               -0.04            0.08              -0.13            0.01
# 35               -0.02            0.02              -0.01           -0.00
# 36               -0.15            0.21               0.06            0.26
# 37               -0.05            0.24               0.06            0.21
# 38                0.10            0.27               0.22            0.22
# 39                0.08            0.06               0.04            0.09
# 40               -0.03           -0.05              -0.00            0.15
# 41               -0.07            0.17               0.04            0.13
# 42               -0.19            0.15              -0.03            0.17
# 43                 NaN             NaN                NaN             NaN
# 44                 NaN             NaN                NaN             NaN
# 45                0.00            0.23               0.24            0.30
# 46               -0.09            0.23               0.18            0.31
# 47               -0.04            0.06               0.03            0.01
# 48                0.03            0.10               0.02            0.11
# 49               -0.06            0.09              -0.05            0.00
# 50               -0.11            0.21               0.15            0.28
# 51                 NaN             NaN                NaN             NaN
# 52               -0.07            0.12               0.08            0.14
# 53               -0.03            0.16               0.02            0.17
# 54               -0.07            0.03              -0.02            0.09
# 55                0.02            0.14               0.04            0.11
# 56                 NaN             NaN                NaN             NaN
# 57               -0.04            0.00               0.04            0.10
# 58                0.01           -0.00               0.11            0.12
# 59                0.10           -0.14               0.04            0.08
# 60                 NaN             NaN                NaN             NaN
# 61               -0.05            0.12               0.01            0.09
# 62               -0.07            0.02               0.01            0.06
# 63               -0.06            0.12              -0.01            0.15
# 64               -0.06            0.08               0.06            0.20
# 65                0.13            0.30               0.26            0.28
# 66                0.06            0.32               0.19            0.28
# 67               -0.08            0.09               0.03            0.08
# 68                0.11            0.37               0.27            0.29
# 69                0.05            0.01              -0.05            0.05
# 70               -0.04            0.08               0.03            0.05
# 71               -0.03            0.04              -0.01            0.07
# 72               -0.11            0.28               0.14            0.22
# 73               -0.06            0.27               0.08            0.17
# 74                 NaN             NaN                NaN             NaN
# 75               -0.08            0.20               0.06            0.15
# 76               -0.03            0.12               0.12            0.00
# 77                 NaN             NaN                NaN             NaN
# 78               -0.13            0.17               0.15            0.17
# 79               -0.07            0.23               0.08            0.18
# 80               -0.08            0.18               0.02            0.18
# 81                0.03           -0.20               0.19            0.17
# 82               -0.02            0.25               0.15            0.23
# 83                0.03            0.12               0.01            0.05
# 84               -0.04            0.02              -0.00            0.04
# 85                0.03            0.33               0.20            0.25
# 86                0.06            0.35               0.22            0.27
# 87                0.12            0.37               0.23            0.34
# 88               -0.06             NaN              -0.16            0.19
# 89               -0.01            0.12               0.08            0.19
# 90               -0.01            0.08               0.05            0.11
# 91               -0.04            0.09               0.02            0.09
# 92               -0.02            0.20               0.22            0.29
# 93                0.04            0.14              -0.12            0.12
# 94               -0.04            0.13              -0.04            0.08
# 95                0.01            0.27               0.13            0.26
# 96               -0.02             NaN                NaN            0.07
# 97                0.10            0.33               0.26            0.29
# 98               -0.05            0.03               0.03            0.04
# 99               -0.02            0.38               0.17            0.28
# 100              -0.00            0.05              -0.03            0.04
# 101               0.01            0.27               0.14            0.14
# 102              -0.02           -0.04              -0.03            0.09
# 103              -0.01            0.08               0.01            0.09
# 104               0.10            0.21               0.01            0.20
# 105               0.07            0.08               0.02            0.02
#
#      freedom_nationalism  freedom_religiosity  socialism_family  \
# 0                  -0.04                -0.07             -0.11
# 1                  -0.11                -0.05              0.05
# 2                  -0.06                -0.08             -0.02
# 3                  -0.19                -0.14              0.05
# 4                  -0.21                -0.16              0.05
# 5                  -0.19                -0.19              0.04
# 6                   0.00                -0.19              0.15
# 7                  -0.12                -0.10             -0.05
# 8                    NaN                  NaN              0.02
# 9                  -0.10                -0.13             -0.05
# 10                 -0.16                -0.15             -0.08
# 11                 -0.20                -0.15             -0.05
# 12                 -0.04                -0.10             -0.13
# 13                  0.03                -0.06             -0.01
# 14                 -0.17                -0.11             -0.12
# 15                 -0.14                -0.21              0.08
# 16                 -0.10                -0.14              0.10
# 17                 -0.07                -0.05             -0.05
# 18                 -0.17                -0.16             -0.02
# 19                 -0.16                -0.26             -0.15
# 20                 -0.10                -0.18             -0.11
# 21                  0.01                -0.11             -0.13
# 22                 -0.17                -0.06              0.03
# 23                 -0.11                -0.22             -0.06
# 24                 -0.06                -0.08              0.03
# 25                 -0.10                -0.15             -0.10
# 26                 -0.07                -0.16             -0.02
# 27                  0.04                -0.16             -0.08
# 28                 -0.07                -0.11              0.02
# 29                 -0.18                -0.09              0.07
# 30                 -0.03                -0.01             -0.00
# 31                 -0.23                -0.10              0.03
# 32                 -0.00                -0.09             -0.03
# 33                 -0.02                -0.35             -0.07
# 34                 -0.12                -0.15              0.08
# 35                  0.03                 0.02              0.02
# 36                 -0.03                -0.01             -0.05
# 37                 -0.04                -0.11             -0.05
# 38                 -0.22                -0.16              0.02
# 39                 -0.04                -0.03              0.00
# 40                  0.03                -0.03              0.05
# 41                 -0.16                -0.19             -0.05
# 42                 -0.21                -0.13              0.06
# 43                   NaN                  NaN              0.05
# 44                   NaN                  NaN               NaN
# 45                 -0.11                -0.16             -0.02
# 46                 -0.14                -0.07             -0.11
# 47                 -0.04                -0.07             -0.04
# 48                 -0.07                -0.14              0.00
# 49                 -0.06                -0.16              0.07
# 50                 -0.06                -0.13             -0.04
# 51                   NaN                  NaN               NaN
# 52                 -0.07                -0.15             -0.01
# 53                 -0.00                -0.13             -0.08
# 54                 -0.10                -0.16              0.07
# 55                 -0.07                -0.15              0.03
# 56                   NaN                  NaN             -0.01
# 57                 -0.11                -0.18              0.03
# 58                 -0.06                -0.15              0.05
# 59                  0.04                 0.00             -0.01
# 60                   NaN                  NaN             -0.07
# 61                 -0.10                -0.12              0.01
# 62                 -0.04                -0.03              0.08
# 63                 -0.11                -0.14             -0.08
# 64                 -0.10                -0.16             -0.02
# 65                 -0.12                -0.27              0.06
# 66                 -0.11                -0.18             -0.04
# 67                 -0.14                -0.14             -0.06
# 68                 -0.10                -0.17              0.03
# 69                 -0.05                -0.13              0.08
# 70                 -0.05                -0.09             -0.04
# 71                 -0.01                -0.09              0.04
# 72                 -0.08                -0.25             -0.07
# 73                  0.06                -0.15             -0.07
# 74                   NaN                  NaN             -0.02
# 75                 -0.07                -0.22             -0.11
# 76                  0.00                -0.06              0.05
# 77                   NaN                  NaN               NaN
# 78                 -0.19                -0.13             -0.10
# 79                 -0.08                -0.09             -0.03
# 80                 -0.05                -0.16             -0.07
# 81                 -0.03                -0.02             -0.14
# 82                 -0.11                -0.12             -0.06
# 83                 -0.08                -0.17              0.11
# 84                 -0.03                -0.12              0.05
# 85                 -0.21                -0.22              0.00
# 86                 -0.09                -0.08             -0.02
# 87                 -0.30                -0.16             -0.00
# 88                  0.10                -0.06               NaN
# 89                 -0.11                -0.15             -0.05
# 90                 -0.04                -0.07              0.01
# 91                 -0.01                -0.09              0.17
# 92                 -0.22                -0.25              0.00
# 93                 -0.04                -0.03              0.04
# 94                 -0.04                -0.10             -0.04
# 95                 -0.20                -0.15             -0.09
# 96                 -0.04                -0.08               NaN
# 97                 -0.19                -0.14             -0.00
# 98                 -0.06                -0.11              0.01
# 99                 -0.19                -0.23              0.01
# 100                -0.13                -0.15             -0.18
# 101                -0.18                -0.10             -0.02
# 102                 0.04                 0.03             -0.04
# 103                -0.02                -0.04             -0.03
# 104                -0.22                -0.29              0.12
# 105                -0.25                -0.19              0.24
#
#      socialism_ethnicity  socialism_gender  socialism_nationalism  \
# 0                  -0.05              0.05                   0.05
# 1                    NaN              0.02                  -0.06
# 2                  -0.09             -0.01                  -0.10
# 3                   0.02             -0.01                  -0.01
# 4                   0.02              0.03                  -0.09
# 5                  -0.02              0.00                  -0.07
# 6                  -0.00             -0.03                  -0.13
# 7                  -0.06             -0.03                  -0.07
# 8                   0.05               NaN                  -0.06
# 9                  -0.02              0.00                   0.03
# 10                 -0.21              0.01                  -0.12
# 11                 -0.03             -0.06                  -0.00
# 12                 -0.10             -0.12                  -0.01
# 13                 -0.12             -0.12                  -0.04
# 14                 -0.08             -0.02                   0.05
# 15                 -0.03             -0.07                  -0.11
# 16                  0.01             -0.03                  -0.09
# 17                 -0.04             -0.04                   0.01
# 18                  0.04             -0.03                   0.03
# 19                 -0.06              0.12                  -0.04
# 20                 -0.03             -0.08                  -0.05
# 21                 -0.07             -0.08                  -0.08
# 22                  0.05              0.05                  -0.13
# 23                 -0.01             -0.03                   0.11
# 24                 -0.01             -0.04                  -0.00
# 25                   NaN             -0.05                   0.02
# 26                 -0.02             -0.07                   0.00
# 27                 -0.08             -0.02                  -0.16
# 28                  0.02              0.01                  -0.09
# 29                  0.10              0.03                  -0.05
# 30                 -0.01             -0.07                  -0.10
# 31                  0.05              0.05                  -0.13
# 32                  0.07              0.00                  -0.01
# 33                  0.09             -0.01                  -0.10
# 34                 -0.08             -0.08                  -0.01
# 35                 -0.01              0.02                  -0.02
# 36                 -0.03             -0.09                  -0.01
# 37                 -0.01             -0.04                  -0.09
# 38                  0.05              0.05                  -0.13
# 39                 -0.02              0.01                  -0.04
# 40                  0.03             -0.04                   0.04
# 41                 -0.04             -0.05                   0.04
# 42                  0.06             -0.01                   0.07
# 43                 -0.08               NaN                  -0.06
# 44                   NaN               NaN                    NaN
# 45                  0.02             -0.06                  -0.11
# 46                 -0.02             -0.07                  -0.06
# 47                 -0.04             -0.01                  -0.06
# 48                 -0.05             -0.00                  -0.02
# 49                  0.06             -0.03                  -0.00
# 50                 -0.06             -0.08                  -0.06
# 51                  0.00              0.07                   0.08
# 52                 -0.02             -0.07                   0.01
# 53                 -0.04             -0.04                  -0.18
# 54                  0.04             -0.04                   0.03
# 55                 -0.12              0.03                  -0.20
# 56                 -0.04               NaN                    NaN
# 57                  0.01             -0.03                   0.04
# 58                  0.03              0.13                  -0.07
# 59                 -0.13             -0.13                   0.02
# 60                 -0.04               NaN                  -0.18
# 61                  0.01             -0.04                  -0.03
# 62                 -0.05             -0.10                  -0.12
# 63                 -0.06             -0.03                  -0.05
# 64                  0.01              0.07                  -0.09
# 65                  0.05              0.03                  -0.13
# 66                  0.00             -0.01                  -0.07
# 67                 -0.02             -0.06                   0.08
# 68                  0.05              0.01                  -0.10
# 69                  0.04              0.14                  -0.21
# 70                  0.01             -0.09                  -0.01
# 71                 -0.02              0.01                   0.01
# 72                 -0.10             -0.13                  -0.08
# 73                 -0.02             -0.01                  -0.08
# 74                  0.10             -0.05                   0.02
# 75                 -0.01             -0.08                  -0.04
# 76                 -0.08             -0.03                   0.02
# 77                   NaN               NaN                    NaN
# 78                 -0.04             -0.08                   0.02
# 79                  0.02             -0.08                  -0.08
# 80                 -0.03             -0.07                  -0.10
# 81                  0.05             -0.06                   0.05
# 82                 -0.02              0.01                  -0.09
# 83                  0.01             -0.12                  -0.03
# 84                  0.06             -0.04                   0.02
# 85                  0.05             -0.03                  -0.06
# 86                 -0.00             -0.01                  -0.11
# 87                  0.04              0.08                  -0.12
# 88                 -0.05             -0.13                  -0.08
# 89                  0.03              0.02                  -0.02
# 90                  0.05              0.01                   0.00
# 91                 -0.05              0.03                  -0.01
# 92                 -0.08             -0.09                  -0.10
# 93                 -0.00              0.11                  -0.12
# 94                 -0.07             -0.02                  -0.06
# 95                 -0.07             -0.08                  -0.10
# 96                  0.01             -0.11                  -0.07
# 97                  0.00             -0.00                  -0.12
# 98                 -0.09              0.03                  -0.03
# 99                  0.00             -0.01                  -0.12
# 100                -0.11              0.01                  -0.03
# 101                 0.00             -0.02                  -0.04
# 102                 0.12             -0.01                   0.02
# 103                 0.00             -0.00                  -0.02
# 104                 0.01              0.05                  -0.08
# 105                -0.03             -0.12                  -0.13
#
#      socialism_religiosity  family_ethnicity  family_gender  \
# 0                     0.05              0.12           0.01
# 1                    -0.17              0.11           0.03
# 2                    -0.01              0.14           0.15
# 3                     0.01              0.12           0.24
# 4                     0.02              0.16           0.45
# 5                     0.03              0.20           0.35
# 6                    -0.11              0.10          -0.02
# 7                     0.01              0.16           0.05
# 8                    -0.04              0.19            NaN
# 9                     0.07              0.06           0.10
# 10                    0.08              0.12           0.14
# 11                    0.00              0.11           0.21
# 12                    0.07              0.13           0.11
# 13                   -0.04              0.06           0.08
# 14                    0.07              0.06           0.09
# 15                   -0.03              0.14           0.35
# 16                   -0.01              0.13           0.21
# 17                    0.02              0.09           0.06
# 18                    0.04              0.05           0.20
# 19                    0.11              0.19           0.27
# 20                    0.05              0.07           0.24
# 21                    0.07              0.07           0.21
# 22                    0.01              0.22           0.41
# 23                    0.13              0.08           0.20
# 24                    0.01              0.05           0.05
# 25                   -0.01               NaN           0.03
# 26                   -0.07             -0.27           0.03
# 27                    0.10              0.09           0.19
# 28                    0.02              0.25           0.39
# 29                   -0.02              0.24           0.33
# 30                   -0.07              0.12           0.06
# 31                    0.01              0.23           0.36
# 32                   -0.02             -0.02          -0.04
# 33                   -0.04              0.22           0.25
# 34                    0.03             -0.04          -0.01
# 35                   -0.02             -0.04           0.03
# 36                    0.10              0.16           0.17
# 37                    0.05              0.09           0.24
# 38                    0.02              0.38           0.41
# 39                   -0.01             -0.01           0.00
# 40                   -0.01              0.01          -0.04
# 41                    0.08              0.06           0.13
# 42                    0.01             -0.10           0.06
# 43                   -0.02              0.16            NaN
# 44                     NaN               NaN            NaN
# 45                    0.03              0.19           0.37
# 46                    0.01              0.13           0.32
# 47                   -0.10              0.05           0.09
# 48                   -0.08              0.11           0.07
# 49                   -0.05             -0.03          -0.05
# 50                   -0.01              0.15           0.26
# 51                     NaN               NaN            NaN
# 52                    0.04              0.14           0.15
# 53                    0.01              0.10           0.22
# 54                   -0.08              0.06           0.07
# 55                    0.05              0.10           0.15
# 56                    0.04              0.14            NaN
# 57                    0.05              0.09           0.03
# 58                   -0.03              0.15           0.25
# 59                   -0.05             -0.10          -0.03
# 60                   -0.02              0.06            NaN
# 61                    0.00              0.06           0.15
# 62                    0.15             -0.13           0.05
# 63                    0.08              0.09           0.11
# 64                    0.04             -0.11           0.08
# 65                   -0.05              0.13           0.38
# 66                    0.01              0.14           0.42
# 67                    0.03             -0.05           0.10
# 68                   -0.02              0.31           0.40
# 69                   -0.03              0.02           0.03
# 70                    0.02              0.03           0.06
# 71                   -0.02              0.03          -0.00
# 72                    0.05              0.17           0.26
# 73                    0.07              0.14           0.37
# 74                     NaN              0.03          -0.04
# 75                    0.12              0.10           0.16
# 76                    0.03             -0.11           0.01
# 77                     NaN              0.05           0.11
# 78                    0.10              0.10           0.19
# 79                   -0.04              0.06           0.27
# 80                    0.04              0.08           0.22
# 81                    0.06             -0.15          -0.01
# 82                    0.10              0.22           0.38
# 83                   -0.09              0.02          -0.06
# 84                   -0.05              0.04           0.02
# 85                   -0.02              0.22           0.36
# 86                    0.03              0.27           0.30
# 87                    0.05              0.15           0.38
# 88                   -0.00               NaN            NaN
# 89                   -0.02              0.08           0.11
# 90                   -0.04              0.04           0.14
# 91                    0.00              0.10           0.16
# 92                    0.01              0.16           0.18
# 93                    0.02             -0.10           0.18
# 94                   -0.01              0.06           0.08
# 95                    0.13              0.12           0.32
# 96                   -0.06             -0.01           0.01
# 97                    0.02              0.23           0.40
# 98                   -0.04              0.02           0.01
# 99                   -0.03              0.11           0.36
# 100                  -0.04             -0.01          -0.01
# 101                   0.00              0.21           0.29
# 102                  -0.05             -0.03           0.11
# 103                  -0.03              0.10           0.07
# 104                  -0.15             -0.03           0.05
# 105                   0.01             -0.07          -0.03
#
#      family_nationalism  family_religiosity  ethnicity_gender  \
# 0                 -0.22               -0.17              0.22
# 1                 -0.09               -0.10              0.18
# 2                 -0.04               -0.17              0.02
# 3                 -0.14               -0.32              0.20
# 4                 -0.19               -0.43              0.24
# 5                 -0.13               -0.42              0.26
# 6                 -0.02               -0.02              0.10
# 7                 -0.16               -0.22              0.13
# 8                 -0.13               -0.36               NaN
# 9                 -0.06               -0.19              0.10
# 10                -0.13               -0.18              0.15
# 11                -0.11               -0.21              0.16
# 12                -0.13               -0.14              0.01
# 13                -0.01               -0.05              0.22
# 14                -0.18               -0.19              0.07
# 15                -0.19               -0.44              0.31
# 16                -0.20               -0.28              0.20
# 17                -0.04               -0.06              0.20
# 18                -0.12               -0.19              0.11
# 19                -0.27               -0.41              0.14
# 20                -0.03               -0.32              0.17
# 21                -0.11               -0.33              0.15
# 22                -0.02               -0.37              0.29
# 23                -0.16               -0.28             -0.02
# 24                -0.01               -0.12              0.05
# 25                -0.03               -0.16               NaN
# 26                -0.08               -0.07              0.22
# 27                -0.07               -0.22              0.03
# 28                -0.03               -0.39              0.31
# 29                -0.06               -0.33              0.30
# 30                -0.15               -0.19              0.08
# 31                -0.12               -0.36              0.30
# 32                 0.01               -0.09              0.08
# 33                -0.03               -0.41              0.24
# 34                 0.01               -0.10              0.11
# 35                 0.01                0.03             -0.02
# 36                -0.06               -0.20              0.19
# 37                -0.15               -0.26              0.10
# 38                -0.22               -0.34              0.35
# 39                -0.07               -0.20              0.12
# 40                -0.10               -0.11             -0.01
# 41                -0.17               -0.27              0.06
# ...
# 64                 0.09               -0.07              0.09
# 65                -0.06               -0.51              0.25
# 66                -0.08               -0.48              0.24
# 67                -0.03               -0.18              0.11
# 68                 0.01               -0.42              0.32
# 69                -0.18               -0.06              0.14
# 70                -0.06               -0.13              0.12
# 71                 0.00               -0.05              0.11
# 72                -0.12               -0.41              0.30
# 73                 0.02               -0.30              0.26
# 74                -0.04                 NaN              0.10
# 75                -0.09               -0.28              0.23
# 76                 0.01               -0.05              0.06
# 77                  NaN               -0.05              0.17
# 78                -0.11               -0.16              0.17
# 79                -0.07               -0.23              0.17
# 80                -0.07               -0.35              0.09
# 81                -0.07               -0.13              0.16
# 82                -0.16               -0.35              0.24
# 83                -0.05               -0.19              0.14
# 84                -0.02               -0.12              0.12
# 85                -0.24               -0.38              0.25
# 86                -0.01               -0.30              0.27
# 87                -0.19               -0.40              0.27
# 88                  NaN                 NaN              0.22
# 89                -0.10               -0.20              0.28
# 90                -0.04               -0.08              0.16
# 91                 0.03                0.00              0.23
# 92                -0.16               -0.23              0.30
# 93                -0.15                0.02              0.03
# 94                -0.05               -0.25              0.06
# 95                -0.04               -0.31              0.21
# 96                  NaN               -0.05              0.06
# 97                -0.12               -0.39              0.30
# 98                -0.08               -0.12              0.13
# 99                -0.22               -0.45              0.27
# 100               -0.05               -0.10              0.17
# 101               -0.14               -0.29              0.25
# 102                0.01                0.08              0.04
# 103               -0.15               -0.18              0.12
# 104               -0.05               -0.19              0.24
# 105               -0.00               -0.06              0.13
#
#      ethnicity_nationalism  ethnicity_religiosity  gender_nationalism  \
# 0                    -0.02                  -0.05                0.11
# 1                      NaN                  -0.01               -0.03
# 2                     0.12                  -0.02               -0.07
# 3                    -0.11                  -0.08               -0.09
# 4                    -0.08                   0.03               -0.19
# 5                    -0.12                  -0.03               -0.10
# 6                    -0.03                   0.05                0.06
# 7                    -0.01                  -0.09                0.01
# 8                    -0.04                   0.02                 NaN
# 9                    -0.06                  -0.04               -0.05
# 10                    0.10                  -0.08               -0.15
# 11                   -0.08                  -0.07               -0.13
# 12                   -0.04                  -0.02                0.05
# 13                   -0.02                  -0.00               -0.04
# 14                    0.03                  -0.00               -0.04
# 15                    0.01                  -0.03               -0.13
# 16                   -0.04                  -0.04               -0.09
# 17                    0.01                  -0.02                0.04
# 18                   -0.04                  -0.03               -0.10
# 19                   -0.09                  -0.07               -0.17
# 20                    0.01                  -0.10               -0.03
# 21                    0.07                  -0.05                0.04
# 22                   -0.10                  -0.06               -0.07
# 23                   -0.02                   0.02               -0.05
# 24                    0.05                  -0.07               -0.01
# 25                     NaN                    NaN               -0.02
# 26                    0.02                  -0.15               -0.05
# 27                   -0.02                   0.05                0.07
# 28                   -0.04                   0.01                0.06
# 29                   -0.09                   0.00               -0.02
# 30                   -0.06                  -0.02                0.02
# 31                   -0.11                   0.02               -0.11
# 32                   -0.05                  -0.01               -0.02
# 33                   -0.05                  -0.22                0.02
# 34                    0.00                  -0.00                0.02
# 35                    0.03                  -0.05               -0.10
# 36                    0.03                   0.03               -0.02
# 37                    0.01                  -0.05               -0.04
# 38                   -0.15                  -0.14               -0.13
# 39                   -0.05                  -0.04                0.04
# 40                    0.08                   0.01               -0.02
# 41                   -0.03                  -0.05               -0.12
# 42                   -0.02                    NaN               -0.07
# 43                   -0.08                  -0.05                 NaN
# 44                     NaN                    NaN                 NaN
# 45                   -0.06                  -0.05               -0.01
# 46                   -0.07                  -0.01               -0.21
# 47                   -0.08                  -0.03               -0.05
# 48                    0.04                   0.00               -0.04
# 49                    0.11                   0.01                0.06
# 50                   -0.01                   0.07               -0.08
# 51                    0.04                    NaN               -0.12
# 52                   -0.07                  -0.07               -0.15
# 53                   -0.19                   0.00                0.01
# 54                    0.01                   0.04               -0.08
# 55                    0.08                  -0.06               -0.04
# 56                   -0.11                   0.01                 NaN
# 57                   -0.10                  -0.06               -0.13
# 58                   -0.19                  -0.12               -0.14
# 59                   -0.09                   0.01               -0.07
# 60                   -0.08                  -0.03                 NaN
# 61                   -0.03                  -0.03                0.01
# 62                    0.06                  -0.13                0.05
# 63                   -0.01                  -0.07               -0.11
# 64                   -0.02                  -0.13               -0.13
# 65                   -0.02                  -0.03               -0.04
# 66                   -0.01                   0.05               -0.09
# 67                    0.05                  -0.08                0.01
# 68                   -0.04                  -0.01                0.01
# 69                   -0.03                   0.02               -0.20
# 70                   -0.02                   0.03               -0.05
# 71                    0.00                  -0.01               -0.02
# 72                   -0.01                  -0.11               -0.02
# 73                   -0.03                  -0.01                0.06
# 74                   -0.05                    NaN                0.01
# 75                   -0.06                  -0.06               -0.04
# 76                   -0.13                  -0.10                0.17
# 77                     NaN                  -0.08                 NaN
# 78                   -0.09                  -0.05               -0.08
# 79                    0.07                   0.02                0.06
# 80                    0.10                  -0.03               -0.03
# 81                   -0.04                   0.06                0.01
# 82                   -0.09                  -0.07               -0.10
# 83                    0.01                   0.01               -0.05
# 84                    0.00                  -0.03               -0.04
# 85                   -0.11                  -0.08               -0.16
# 86                   -0.02                   0.05                0.00
# 87                   -0.19                  -0.00               -0.23
# 88                    0.07                  -0.06                0.14
# 89                   -0.10                  -0.09               -0.04
# 90                   -0.02                  -0.03               -0.05
# 91                    0.04                  -0.06                0.06
# 92                   -0.10                  -0.17               -0.05
# 93                    0.09                  -0.01               -0.26
# 94                   -0.04                  -0.04               -0.05
# 95                   -0.04                  -0.06               -0.09
# 96                    0.11                  -0.01               -0.00
# 97                   -0.08                   0.06               -0.08
# 98                    0.03                   0.02                0.10
# 99                   -0.05                  -0.01               -0.16
# 100                  -0.04                   0.01               -0.04
# 101                  -0.13                  -0.06               -0.08
# 102                  -0.04                   0.01               -0.06
# 103                  -0.09                  -0.05               -0.02
# 104                  -0.13                  -0.14               -0.10
# 105                   0.07                   0.03                0.03
#
#      gender_religiosity  nationalism_religiosity
# 0                 -0.10                    -0.00
# 1                 -0.10                     0.15
# 2                 -0.10                     0.10
# 3                 -0.10                     0.17
# 4                 -0.16                     0.00
# 5                 -0.12                     0.05
# 6                 -0.05                     0.05
# 7                  0.06                     0.14
# 8                   NaN                     0.06
# 9                 -0.03                     0.06
# 10                -0.01                     0.09
# 11                -0.02                     0.10
# 12                -0.06                    -0.01
# 13                 0.02                     0.09
# 14                 0.00                     0.02
# 15                -0.18                     0.12
# 16                -0.06                     0.14
# 17                -0.07                    -0.02
# 18                -0.00                     0.09
# 19                -0.12                     0.17
# 20                -0.06                     0.08
# 21                -0.12                     0.00
# 22                -0.14                     0.08
# 23                -0.10                     0.12
# 24                -0.04                     0.01
# 25                 0.13                    -0.01
# 26                -0.13                     0.04
# 27                -0.06                    -0.11
# 28                -0.13                     0.04
# 29                -0.16                    -0.01
# 30                 0.10                     0.11
# 31                -0.16                     0.03
# 32                 0.04                     0.05
# 33                -0.27                     0.05
# 34                 0.09                     0.06
# 35                -0.02                     0.01
# 36                -0.01                     0.04
# 37                -0.08                    -0.03
# 38                -0.09                     0.14
# 39                -0.05                     0.05
# 40                 0.06                     0.14
# 41                -0.14                     0.25
# 42                -0.13                     0.05
# 43                  NaN                     0.08
# 44                  NaN                      NaN
# 45                -0.12                     0.11
# 46                -0.13                     0.18
# 47                -0.08                     0.05
# 48                -0.14                     0.11
# 49                 0.16                     0.12
# 50                 0.01                     0.09
# 51                  NaN                      NaN
# 52                -0.20                     0.09
# 53                -0.07                    -0.04
# 54                -0.09                     0.15
# 55                -0.05                     0.04
# 56                  NaN                    -0.01
# 57                -0.10                     0.25
# 58                -0.10                     0.14
# 59                 0.05                     0.02
# 60                  NaN                     0.13
# 61                -0.04                     0.06
# 62                -0.16                    -0.09
# 63                -0.05                     0.04
# 64                -0.07                     0.10
# 65                -0.23                     0.06
# 66                -0.12                    -0.03
# 67                -0.02                    -0.00
# 68                -0.22                    -0.05
# 69                 0.06                     0.16
# 70                 0.02                     0.05
# 71                -0.00                     0.03
# 72                -0.17                     0.13
# 73                -0.11                    -0.07
# 74                  NaN                      NaN
# 75                -0.09                     0.02
# 76                 0.04                     0.08
# 77                -0.04                      NaN
# 78                -0.07                     0.06
# 79                -0.09                     0.09
# 80                -0.05                     0.01
# 81                -0.09                    -0.05
# 82                -0.14                     0.07
# 83                 0.07                     0.07
# 84                 0.05                    -0.02
# 85                -0.20                     0.14
# 86                -0.07                    -0.04
# 87                -0.13                     0.08
# 88                -0.13                     0.03
# 89                -0.14                     0.12
# 90                -0.02                     0.03
# 91                -0.16                     0.12
# 92                -0.25                     0.24
# 93                 0.12                    -0.02
# 94                -0.01                     0.12
# 95                -0.16                    -0.11
# 96                -0.05                     0.16
# 97                -0.18                    -0.00
# 98                 0.07                     0.08
# 99                -0.12                     0.13
# 100                0.02                     0.10
# 101               -0.02                     0.06
# 102               -0.07                    -0.03
# 103                0.01                     0.08
# 104               -0.29                     0.17
# 105                0.16                     0.22

# %% [markdown]
# ## The regression_models() method

# %%
for i in CountryLevelDataAnalyzer.correlation_names:
    exec(f"print(['{i}', round(CountryLevelDataAnalyzer.{i}_score, 2)])")
# Out:
# ['freedom_socialism', 0.34]
# ['freedom_family', 0.63]
# ['freedom_ethnicity', 0.5]
# ['freedom_gender', 0.5]
# ['freedom_nationalism', 0.18]
# ['freedom_religiosity', 0.14]
# ['socialism_family', 0.2]
# ['socialism_ethnicity', 0.18]
# ['socialism_gender', 0.05]
# ['socialism_nationalism', 0.24]
# ['socialism_religiosity', 0.19]
# ['family_ethnicity', 0.61]
# ['family_gender', 0.74]
# ['family_nationalism', 0.1]
# ['family_religiosity', 0.73]
# ['ethnicity_gender', 0.3]
# ['ethnicity_nationalism', 0.12]
# ['ethnicity_religiosity', 0.05]
# ['gender_nationalism', 0.08]
# ['gender_religiosity', 0.27]
# ['nationalism_religiosity', 0.24]

# %%
CountryLevelDataAnalyzer.family_gender_model.coef_
# Out:
# array([[0.03063081, 0.15387163, 0.41728125, 0.10958928]])

# %%
CountryLevelDataAnalyzer.family_religiosity_model.coef_
# Out:
# array([[-0.03009326, -0.09652887, -0.33036605, -0.18296926]])

# %%
CountryLevelDataAnalyzer.family_ethnicity_model.coef_
# Out:
# array([[0.00867261, 0.0170214 , 0.45844321, 0.0344159 ]])

# %%
CountryLevelDataAnalyzer.freedom_family_model.coef_
# Out:
# array([[0.01410771, 0.10557649, 0.30708496, 0.11618442]])

# %%
CountryLevelDataAnalyzer.freedom_gender_model.coef_
# Out:
# array([[0.00568494, 0.06610076, 0.23933779, 0.05850531]])

# %%
CountryLevelDataAnalyzer.freedom_ethnicity_model.coef_
# Out:
# array([[0.0075514 , 0.11248593, 0.19784395, 0.07069894]])

# %%
CountryLevelDataAnalyzer.freedom_socialism_model.coef_
# Out:
# array([[-0.01653919,  0.11006107, -0.14960354,  0.09376453]])

# %%
CountryLevelDataAnalyzer.ethnicity_gender_model.coef_
# Out:
# array([[-0.00617359,  0.09464071,  0.14103413,  0.02082337]])

# %%
CountryLevelDataAnalyzer.gender_religiosity_model.coef_
# Out:
# array([[-0.01966049, -0.0361413 , -0.31178592,  0.03831286]])

# %%
CountryLevelDataAnalyzer.socialism_nationalism_model.coef_
# Out:
# array([[-0.02491997, -0.01083081,  0.00931982, -0.10930467]])

# %%
CountryLevelDataAnalyzer.nationalism_religiosity_model.coef_
# Out:
# array([[-0.07994186, -0.07590958,  0.1269531 , -0.07524136]])

# %%
CountryLevelDataAnalyzer.socialism_family_model.coef_
# Out:
# array([[-0.04494396,  0.06408819, -0.12649499, -0.02573447]])

# %%
CountryLevelDataAnalyzer.socialism_religiosity_model.coef_
# Out:
# array([[ 0.03479515, -0.03354578,  0.08057008,  0.05167406]])

# %%
CountryLevelDataAnalyzer.freedom_nationalism_model.coef_
# Out:
# array([[ 0.01294754, -0.07451907, -0.09116321,  0.00937008]])

# %%
CountryLevelDataAnalyzer.socialism_ethnicity_model.coef_
# Out:
# array([[-0.03571859,  0.0272408 ,  0.09470936, -0.05036362]])

# %%
CountryLevelDataAnalyzer.freedom_religiosity_model.coef_
# Out:
# array([[ 0.03234512,  0.02209559, -0.05140664, -0.06053201]])

# %%
CountryLevelDataAnalyzer.ethnicity_nationalism_model.coef_
# Out:
# array([[ 0.01547906, -0.03818682, -0.03327712, -0.01726407]])

# %%
CountryLevelDataAnalyzer.family_nationalism_model.coef_
# Out:
# array([[-0.01937848, -0.0050575 , -0.14739706,  0.00233549]])

# %%
CountryLevelDataAnalyzer.gender_nationalism_model.coef_
# Out:
# array([[ 0.02492735, -0.03318999, -0.07692823,  0.02110023]])

# %%
CountryLevelDataAnalyzer.socialism_gender_model.coef_
# Out:
# array([[-0.01082418,  0.04204323, -0.00263447, -0.01744316]])

# %%
CountryLevelDataAnalyzer.ethnicity_religiosity_model.coef_
# Out:
# array([[ 0.00739048,  0.05127888,  0.00025654, -0.02367227]])

# %% [markdown]
# ## Statsmodels regressions

# %%
CountryLevelDataAnalyzer.family_gender_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          family_gender   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     66.55
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           1.36e-26
# Time:                        15:12:54   Log-Likelihood:                 121.27
# No. Observations:                  99   AIC:                            -232.5
# Df Residuals:                      94   BIC:                            -219.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.2175      0.038     -5.701      0.000      -0.293      -0.142
# authoritarian_socialism     0.0306      0.018      1.702      0.092      -0.005       0.066
# culture_zone                0.1539      0.034      4.520      0.000       0.086       0.221
# hdi2010                     0.4173      0.066      6.282      0.000       0.285       0.549
# v2x_libdem                  0.1096      0.038      2.916      0.004       0.035       0.184
# ==============================================================================
# Omnibus:                        1.748   Durbin-Watson:                   2.260
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                1.179
# Skew:                           0.186   Prob(JB):                        0.555
# Kurtosis:                       3.383   Cond. No.                         14.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.family_religiosity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     family_religiosity   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     66.19
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           6.87e-27
# Time:                        15:33:47   Log-Likelihood:                 128.06
# No. Observations:                 102   AIC:                            -246.1
# Df Residuals:                      97   BIC:                            -233.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.1306      0.037      3.509      0.001       0.057       0.204
# authoritarian_socialism    -0.0301      0.018     -1.713      0.090      -0.065       0.005
# culture_zone               -0.0965      0.032     -3.011      0.003      -0.160      -0.033
# hdi2010                    -0.3304      0.066     -4.995      0.000      -0.462      -0.199
# v2x_libdem                 -0.1830      0.037     -4.920      0.000      -0.257      -0.109
# ==============================================================================
# Omnibus:                        2.087   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                1.566
# Skew:                           0.282   Prob(JB):                        0.457
# Kurtosis:                       3.227   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.family_ethnicity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       family_ethnicity   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.590
# Method:                 Least Squares   F-statistic:                     37.34
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           7.08e-19
# Time:                        15:36:43   Log-Likelihood:                 134.54
# No. Observations:                 102   AIC:                            -259.1
# Df Residuals:                      97   BIC:                            -246.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.2542      0.035     -7.313      0.000      -0.323      -0.185
# authoritarian_socialism     0.0087      0.016      0.530      0.597      -0.024       0.041
# culture_zone                0.0170      0.030      0.567      0.572      -0.043       0.077
# hdi2010                     0.4584      0.060      7.600      0.000       0.339       0.578
# v2x_libdem                  0.0344      0.034      1.006      0.317      -0.033       0.102
# ==============================================================================
# Omnibus:                        1.748   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                1.265
# Skew:                          -0.063   Prob(JB):                        0.531
# Kurtosis:                       3.531   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.freedom_family_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         freedom_family   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                     39.17
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           4.88e-19
# Time:                        15:37:59   Log-Likelihood:                 114.79
# No. Observations:                  96   AIC:                            -219.6
# Df Residuals:                      91   BIC:                            -206.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.1340      0.040     -3.363      0.001      -0.213      -0.055
# authoritarian_socialism     0.0141      0.019      0.746      0.458      -0.023       0.052
# culture_zone                0.1056      0.035      2.988      0.004       0.035       0.176
# hdi2010                     0.3071      0.072      4.249      0.000       0.164       0.451
# v2x_libdem                  0.1162      0.041      2.842      0.006       0.035       0.197
# ==============================================================================
# Omnibus:                        7.916   Durbin-Watson:                   1.680
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               15.263
# Skew:                          -0.129   Prob(JB):                     0.000485
# Kurtosis:                       4.936   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.freedom_gender_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         freedom_gender   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     22.96
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           3.23e-13
# Time:                        15:39:42   Log-Likelihood:                 130.44
# No. Observations:                  98   AIC:                            -250.9
# Df Residuals:                      93   BIC:                            -238.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0488      0.035     -1.405      0.163      -0.118       0.020
# authoritarian_socialism     0.0057      0.016      0.347      0.729      -0.027       0.038
# culture_zone                0.0661      0.031      2.149      0.034       0.005       0.127
# hdi2010                     0.2393      0.063      3.803      0.000       0.114       0.364
# v2x_libdem                  0.0585      0.035      1.662      0.100      -0.011       0.128
# ==============================================================================
# Omnibus:                       16.685   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.063
# Skew:                           0.866   Prob(JB):                     2.67e-05
# Kurtosis:                       4.468   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.freedom_ethnicity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      freedom_ethnicity   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     22.50
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           6.10e-13
# Time:                        15:50:31   Log-Likelihood:                 114.80
# No. Observations:                  96   AIC:                            -219.6
# Df Residuals:                      91   BIC:                            -206.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.1131      0.040     -2.833      0.006      -0.192      -0.034
# authoritarian_socialism     0.0076      0.019      0.402      0.689      -0.030       0.045
# culture_zone                0.1125      0.035      3.185      0.002       0.042       0.183
# hdi2010                     0.1978      0.072      2.737      0.007       0.054       0.341
# v2x_libdem                  0.0707      0.041      1.738      0.086      -0.010       0.152
# ==============================================================================
# Omnibus:                        3.387   Durbin-Watson:                   2.457
# Prob(Omnibus):                  0.184   Jarque-Bera (JB):                2.730
# Skew:                           0.317   Prob(JB):                        0.255
# Kurtosis:                       3.529   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.freedom_socialism_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      freedom_socialism   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.312
# Method:                 Least Squares   F-statistic:                     11.98
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           6.79e-08
# Time:                        15:50:37   Log-Likelihood:                 133.29
# No. Observations:                  98   AIC:                            -256.6
# Df Residuals:                      93   BIC:                            -243.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0266      0.034      0.788      0.432      -0.040       0.094
# authoritarian_socialism    -0.0165      0.016     -1.040      0.301      -0.048       0.015
# culture_zone                0.1101      0.030      3.683      0.000       0.051       0.169
# hdi2010                    -0.1496      0.061     -2.447      0.016      -0.271      -0.028
# v2x_libdem                  0.0938      0.034      2.743      0.007       0.026       0.162
# ==============================================================================
# Omnibus:                        0.043   Durbin-Watson:                   1.626
# Prob(Omnibus):                  0.979   Jarque-Bera (JB):                0.132
# Skew:                          -0.048   Prob(JB):                        0.936
# Kurtosis:                       2.848   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.ethnicity_gender_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       ethnicity_gender   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     10.36
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           5.24e-07
# Time:                        15:52:46   Log-Likelihood:                 116.54
# No. Observations:                 100   AIC:                            -223.1
# Df Residuals:                      95   BIC:                            -210.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0463      0.040      1.146      0.255      -0.034       0.127
# authoritarian_socialism    -0.0062      0.019     -0.329      0.743      -0.043       0.031
# culture_zone                0.0946      0.036      2.638      0.010       0.023       0.166
# hdi2010                     0.1410      0.069      2.030      0.045       0.003       0.279
# v2x_libdem                  0.0208      0.040      0.527      0.599      -0.058       0.099
# ==============================================================================
# Omnibus:                        0.980   Durbin-Watson:                   2.196
# Prob(Omnibus):                  0.613   Jarque-Bera (JB):                1.015
# Skew:                          -0.228   Prob(JB):                        0.602
# Kurtosis:                       2.813   Cond. No.                         14.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.gender_religiosity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     gender_religiosity   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     8.663
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           5.37e-06
# Time:                        15:54:15   Log-Likelihood:                 112.49
# No. Observations:                  99   AIC:                            -215.0
# Df Residuals:                      94   BIC:                            -202.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.1418      0.042      3.375      0.001       0.058       0.225
# authoritarian_socialism    -0.0197      0.020     -0.999      0.320      -0.059       0.019
# culture_zone               -0.0361      0.037     -0.970      0.335      -0.110       0.038
# hdi2010                    -0.3118      0.075     -4.171      0.000      -0.460      -0.163
# v2x_libdem                  0.0383      0.042      0.919      0.361      -0.044       0.121
# ==============================================================================
# Omnibus:                       11.933   Durbin-Watson:                   2.568
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               18.054
# Skew:                          -0.530   Prob(JB):                     0.000120
# Kurtosis:                       4.803   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.socialism_nationalism_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     socialism_nationalism   R-squared:                       0.236
# Model:                               OLS   Adj. R-squared:                  0.204
# Method:                    Least Squares   F-statistic:                     7.553
# Date:                   Sun, 25 Jun 2023   Prob (F-statistic):           2.40e-05
# Time:                           15:55:43   Log-Likelihood:                 149.89
# No. Observations:                    103   AIC:                            -289.8
# Df Residuals:                         98   BIC:                            -276.6
# Df Model:                              4
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0076      0.030      0.251      0.802      -0.052       0.067
# authoritarian_socialism    -0.0249      0.014     -1.766      0.081      -0.053       0.003
# culture_zone               -0.0108      0.026     -0.417      0.677      -0.062       0.041
# hdi2010                     0.0093      0.053      0.177      0.860      -0.095       0.114
# v2x_libdem                 -0.1093      0.030     -3.636      0.000      -0.169      -0.050
# ==============================================================================
# Omnibus:                        7.493   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.726
# Skew:                          -0.476   Prob(JB):                       0.0210
# Kurtosis:                       3.945   Cond. No.                         15.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.nationalism_religiosity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     nationalism_religiosity   R-squared:                       0.240
# Model:                                 OLS   Adj. R-squared:                  0.208
# Method:                      Least Squares   F-statistic:                     7.649
# Date:                     Sun, 25 Jun 2023   Prob (F-statistic):           2.12e-05
# Time:                             15:57:10   Log-Likelihood:                 135.40
# No. Observations:                      102   AIC:                            -260.8
# Df Residuals:                           97   BIC:                            -247.7
# Df Model:                                4
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0617      0.035      1.775      0.079      -0.007       0.131
# authoritarian_socialism    -0.0799      0.016     -4.882      0.000      -0.112      -0.047
# culture_zone               -0.0759      0.030     -2.544      0.013      -0.135      -0.017
# hdi2010                     0.1270      0.063      2.017      0.046       0.002       0.252
# v2x_libdem                 -0.0752      0.035     -2.135      0.035      -0.145      -0.005
# ==============================================================================
# Omnibus:                        0.555   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.758   Jarque-Bera (JB):                0.692
# Skew:                           0.088   Prob(JB):                        0.707
# Kurtosis:                       2.637   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.socialism_family_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       socialism_family   R-squared:                       0.197
# Model:                            OLS   Adj. R-squared:                  0.163
# Method:                 Least Squares   F-statistic:                     5.874
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):           0.000285
# Time:                        15:59:09   Log-Likelihood:                 134.68
# No. Observations:                 101   AIC:                            -259.4
# Df Residuals:                      96   BIC:                            -246.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0925      0.034      2.699      0.008       0.024       0.160
# authoritarian_socialism    -0.0449      0.016     -2.768      0.007      -0.077      -0.013
# culture_zone                0.0641      0.030      2.166      0.033       0.005       0.123
# hdi2010                    -0.1265      0.061     -2.085      0.040      -0.247      -0.006
# v2x_libdem                 -0.0257      0.035     -0.743      0.459      -0.094       0.043
# ==============================================================================
# Omnibus:                       11.479   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               18.014
# Skew:                           0.485   Prob(JB):                     0.000123
# Kurtosis:                       4.827   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.socialism_religiosity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     socialism_religiosity   R-squared:                       0.186
# Model:                               OLS   Adj. R-squared:                  0.153
# Method:                    Least Squares   F-statistic:                     5.546
# Date:                   Sun, 25 Jun 2023   Prob (F-statistic):           0.000460
# Time:                           16:01:21   Log-Likelihood:                 156.73
# No. Observations:                    102   AIC:                            -303.5
# Df Residuals:                         97   BIC:                            -290.3
# Df Model:                              4
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0787      0.028     -2.790      0.006      -0.135      -0.023
# authoritarian_socialism     0.0348      0.013      2.620      0.010       0.008       0.061
# culture_zone               -0.0335      0.024     -1.386      0.169      -0.082       0.014
# hdi2010                     0.0806      0.051      1.578      0.118      -0.021       0.182
# v2x_libdem                  0.0517      0.029      1.807      0.074      -0.005       0.108
# ==============================================================================
# Omnibus:                        2.644   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.267   Jarque-Bera (JB):                2.389
# Skew:                          -0.094   Prob(JB):                        0.303
# Kurtosis:                       3.726   Cond. No.                         15.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.freedom_nationalism_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     freedom_nationalism   R-squared:                       0.185
# Model:                             OLS   Adj. R-squared:                  0.150
# Method:                  Least Squares   F-statistic:                     5.275
# Date:                 Sun, 25 Jun 2023   Prob (F-statistic):           0.000713
# Time:                         16:24:44   Log-Likelihood:                 121.19
# No. Observations:                   98   AIC:                            -232.4
# Df Residuals:                       93   BIC:                            -219.5
# Df Model:                            4
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0238      0.038     -0.622      0.535      -0.100       0.052
# authoritarian_socialism     0.0129      0.018      0.720      0.474      -0.023       0.049
# culture_zone               -0.0745      0.034     -2.204      0.030      -0.142      -0.007
# hdi2010                    -0.0912      0.069     -1.318      0.191      -0.229       0.046
# v2x_libdem                  0.0094      0.039      0.242      0.809      -0.067       0.086
# ==============================================================================
# Omnibus:                        1.968   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.374   Jarque-Bera (JB):                1.396
# Skew:                          -0.250   Prob(JB):                        0.498
# Kurtosis:                       3.304   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.socialism_ethnicity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     socialism_ethnicity   R-squared:                       0.181
# Model:                             OLS   Adj. R-squared:                  0.147
# Method:                  Least Squares   F-statistic:                     5.361
# Date:                 Sun, 25 Jun 2023   Prob (F-statistic):           0.000607
# Time:                         16:25:54   Log-Likelihood:                 160.75
# No. Observations:                  102   AIC:                            -311.5
# Df Residuals:                       97   BIC:                            -298.4
# Df Model:                            4
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0475      0.027     -1.770      0.080      -0.101       0.006
# authoritarian_socialism    -0.0357      0.013     -2.852      0.005      -0.061      -0.011
# culture_zone                0.0272      0.023      1.184      0.239      -0.018       0.073
# hdi2010                     0.0947      0.047      2.021      0.046       0.002       0.188
# v2x_libdem                 -0.0504      0.027     -1.875      0.064      -0.104       0.003
# ==============================================================================
# Omnibus:                        3.723   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.155   Jarque-Bera (JB):                4.146
# Skew:                           0.099   Prob(JB):                        0.126
# Kurtosis:                       3.968   Cond. No.                         15.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.freedom_religiosity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     freedom_religiosity   R-squared:                       0.136
# Model:                             OLS   Adj. R-squared:                  0.099
# Method:                  Least Squares   F-statistic:                     3.662
# Date:                 Sun, 25 Jun 2023   Prob (F-statistic):            0.00815
# Time:                         16:27:07   Log-Likelihood:                 132.28
# No. Observations:                   98   AIC:                            -254.6
# Df Residuals:                       93   BIC:                            -241.6
# Df Model:                            4
# Covariance Type:             nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0816      0.034     -2.391      0.019      -0.149      -0.014
# authoritarian_socialism     0.0323      0.016      2.013      0.047       0.000       0.064
# culture_zone                0.0221      0.030      0.732      0.466      -0.038       0.082
# hdi2010                    -0.0514      0.062     -0.832      0.407      -0.174       0.071
# v2x_libdem                 -0.0605      0.035     -1.753      0.083      -0.129       0.008
# ==============================================================================
# Omnibus:                        1.923   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.382   Jarque-Bera (JB):                1.349
# Skew:                          -0.240   Prob(JB):                        0.509
# Kurtosis:                       3.316   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.ethnicity_nationalism_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ethnicity_nationalism   R-squared:                       0.115
# Model:                               OLS   Adj. R-squared:                  0.079
# Method:                    Least Squares   F-statistic:                     3.161
# Date:                   Sun, 25 Jun 2023   Prob (F-statistic):             0.0173
# Time:                           16:31:28   Log-Likelihood:                 136.68
# No. Observations:                    102   AIC:                            -263.4
# Df Residuals:                         97   BIC:                            -250.2
# Df Model:                              4
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0039      0.034      0.115      0.908      -0.063       0.071
# authoritarian_socialism     0.0155      0.016      0.976      0.332      -0.016       0.047
# culture_zone               -0.0382      0.029     -1.310      0.193      -0.096       0.020
# hdi2010                    -0.0333      0.059     -0.561      0.576      -0.151       0.085
# v2x_libdem                 -0.0173      0.034     -0.508      0.613      -0.085       0.050
# ==============================================================================
# Omnibus:                        0.420   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.811   Jarque-Bera (JB):                0.417
# Skew:                          -0.148   Prob(JB):                        0.812
# Kurtosis:                       2.895   Cond. No.                         15.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.family_nationalism_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     family_nationalism   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     2.663
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):             0.0370
# Time:                        16:34:52   Log-Likelihood:                 124.69
# No. Observations:                 102   AIC:                            -239.4
# Df Residuals:                      97   BIC:                            -226.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.0204      0.038      0.537      0.593      -0.055       0.096
# authoritarian_socialism    -0.0194      0.018     -1.081      0.283      -0.055       0.016
# culture_zone               -0.0051      0.032     -0.157      0.876      -0.069       0.059
# hdi2010                    -0.1474      0.067     -2.192      0.031      -0.281      -0.014
# v2x_libdem                  0.0023      0.039      0.061      0.952      -0.074       0.079
# ==============================================================================
# Omnibus:                        0.709   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.701   Jarque-Bera (JB):                0.306
# Skew:                           0.070   Prob(JB):                        0.858
# Kurtosis:                       3.228   Cond. No.                         15.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.gender_nationalism_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     gender_nationalism   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     1.949
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):              0.109
# Time:                        16:37:17   Log-Likelihood:                 116.98
# No. Observations:                 100   AIC:                            -224.0
# Df Residuals:                      95   BIC:                            -210.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0059      0.040     -0.148      0.883      -0.086       0.074
# authoritarian_socialism     0.0249      0.019      1.325      0.188      -0.012       0.062
# culture_zone               -0.0332      0.036     -0.930      0.355      -0.104       0.038
# hdi2010                    -0.0769      0.070     -1.094      0.277      -0.217       0.063
# v2x_libdem                  0.0211      0.040      0.527      0.600      -0.058       0.101
# ==============================================================================
# Omnibus:                        2.040   Durbin-Watson:                   2.129
# Prob(Omnibus):                  0.361   Jarque-Bera (JB):                1.458
# Skew:                          -0.196   Prob(JB):                        0.482
# Kurtosis:                       3.443   Cond. No.                         14.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.socialism_gender_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       socialism_gender   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.322
# Date:                Sun, 25 Jun 2023   Prob (F-statistic):              0.267
# Time:                        16:38:09   Log-Likelihood:                 146.91
# No. Observations:                 100   AIC:                            -283.8
# Df Residuals:                      95   BIC:                            -270.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0171      0.030     -0.573      0.568      -0.076       0.042
# authoritarian_socialism    -0.0108      0.014     -0.776      0.440      -0.039       0.017
# culture_zone                0.0420      0.026      1.589      0.115      -0.010       0.095
# hdi2010                    -0.0026      0.052     -0.051      0.960      -0.106       0.101
# v2x_libdem                 -0.0174      0.030     -0.587      0.558      -0.076       0.042
# ==============================================================================
# Omnibus:                        7.441   Durbin-Watson:                   2.317
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                6.944
# Skew:                           0.593   Prob(JB):                       0.0311
# Kurtosis:                       3.512   Cond. No.                         14.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
CountryLevelDataAnalyzer.ethnicity_religiosity_statsmodels_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     ethnicity_religiosity   R-squared:                       0.054
# Model:                               OLS   Adj. R-squared:                  0.014
# Method:                    Least Squares   F-statistic:                     1.362
# Date:                   Sun, 25 Jun 2023   Prob (F-statistic):              0.253
# Time:                           16:38:55   Log-Likelihood:                 155.49
# No. Observations:                    101   AIC:                            -301.0
# Df Residuals:                         96   BIC:                            -287.9
# Df Model:                              4
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.0357      0.028     -1.269      0.208      -0.091       0.020
# authoritarian_socialism     0.0074      0.013      0.563      0.575      -0.019       0.033
# culture_zone                0.0513      0.024      2.126      0.036       0.003       0.099
# hdi2010                     0.0003      0.050      0.005      0.996      -0.099       0.099
# v2x_libdem                 -0.0237      0.028     -0.842      0.402      -0.079       0.032
# ==============================================================================
# Omnibus:                        4.665   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                3.992
# Skew:                          -0.442   Prob(JB):                        0.136
# Kurtosis:                       3.410   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
