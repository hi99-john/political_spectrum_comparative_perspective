# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # The class, the object, the data and the methods

# %% [markdown]
# ## Defining the class

# %%
class CountryLevelDataVisualization:
    def loading_country_level_predictors(self):
        self.predictors = pd.read_csv('./country_level_processed_data/country_predictors.csv')
        
    def loading_country_level_correlations(self):
        self.correlations = pd.read_csv('./country_level_processed_data/country_correlations.csv')

    def renaming_country_column(self):
        self.correlations.columns = ['iso_numeric', 'freedom_socialism', 'freedom_family', 'freedom_ethnicity', 'freedom_gender', 'freedom_nationalism', 'freedom_religiosity',
        'socialism_family', 'socialism_ethnicity', 'socialism_gender', 'socialism_nationalism', 'socialism_religiosity', 
        'family_ethnicity', 'family_gender', 'family_nationalism', 'family_religiosity', 
        'ethnicity_gender', 'ethnicity_nationalism', 'ethnicity_religiosity', 
        'gender_nationalism', 'gender_religiosity', 
        'nationalism_religiosity']
        
    def merging_data_frames(self):
        self.predictors_correlations = pd.merge(self.predictors, self.correlations, on ='iso_numeric')

# %% [markdown]
# ## Instantiating the class

# %%
CountryLevelDataVisualizer = CountryLevelDataVisualization()

# %% [markdown]
# ## Caling the methods

# %%
CountryLevelDataVisualizer.loading_country_level_predictors()

# %%
CountryLevelDataVisualizer.loading_country_level_correlations()

# %%
CountryLevelDataVisualizer.renaming_country_column()

# %%
CountryLevelDataVisualizer.merging_data_frames()

# %% [markdown]
# # The results

# %% [markdown]
# ## The loading_country_level_predictors() method

# %%
CountryLevelDataVisualizer.predictors
# Out:
#      iso_numeric iso_alpha_2 iso_alpha3 country_name  authoritarian_socialism  \
# 0              8          AL        ALB      Albania                      1.0
# 1             12          DZ        DZA      Algeria                      0.5
# 2             31          AZ        AZE   Azerbaijan                      1.0
# 3             32          AR        ARG    Argentina                      0.0
# 4             36          AU        AUS    Australia                      0.0
# ..           ...         ...        ...          ...                      ...
# 101          858          UY        URY      Uruguay                      0.0
# 102          860          UZ        UZB   Uzbekistan                      1.0
# 103          862          VE        VEN    Venezuela                      0.5
# 104          887          YE        YEM        Yemen                      0.0
# 105          894          ZM        ZMB       Zambia                      0.5
#
#      culture_zone  hdi2010  v2x_libdem  population
# 0            0.00    0.677       0.341     2913402
# 1            0.00    0.649       0.162    35856348
# 2            0.00    0.622       0.084     9237203
# 3            0.33    0.779       0.662    41100124
# 4            1.00    0.896       0.849    22019166
# ..            ...      ...         ...         ...
# 101          0.33    0.753       0.801     3352653
# 102          0.00    0.607       0.035    28614234
# 103          0.33    0.684       0.312    28715026
# 104          0.00    0.450       0.138    24743944
# 105          0.00    0.418       0.388    13792095
#
# [106 rows x 9 columns]

# %% [markdown]
# ## The loading_country_level_correlations() method

# %%
CountryLevelDataVisualizer.correlations
# Out:
#      iso_numeric  freedom_socialism  freedom_family  freedom_ethnicity  \
# 0              8              -0.05            0.07               0.06
# 1             12              -0.15            0.04              -0.00
# 2             20               0.07            0.32               0.06
# 3             31              -0.01            0.05               0.03
# 4             32              -0.04            0.28               0.18
# ..           ...                ...             ...                ...
# 113          862              -0.01            0.08               0.01
# 114          887               0.10            0.21               0.01
# 115          894               0.07            0.08               0.02
# 116          909               0.01            0.43               0.19
# 117          915                NaN             NaN                NaN
#
#      freedom_gender  freedom_nationalism  freedom_religiosity  \
# 0              0.11                -0.04                -0.07
# 1              0.03                -0.11                -0.05
# 2              0.20                -0.17                -0.10
# 3              0.04                -0.06                -0.08
# 4              0.22                -0.19                -0.14
# ..              ...                  ...                  ...
# 113            0.09                -0.02                -0.04
# 114            0.20                -0.22                -0.29
# 115            0.02                -0.25                -0.19
# 116            0.21                  NaN                -0.09
# 117             NaN                  NaN                  NaN
#
#      socialism_family  socialism_ethnicity  socialism_gender  ...  \
# 0               -0.11                -0.05              0.05  ...
# 1                0.05                  NaN              0.02  ...
# 2               -0.02                 0.10              0.00  ...
# 3               -0.02                -0.09             -0.01  ...
# 4                0.05                 0.02             -0.01  ...
# ..                ...                  ...               ...  ...
# 113             -0.03                 0.00             -0.00  ...
# 114              0.12                 0.01              0.05  ...
# 115              0.24                -0.03             -0.12  ...
# 116             -0.04                -0.13              0.06  ...
# 117              0.04                 0.02               NaN  ...
#
#      family_ethnicity  family_gender  family_nationalism  family_religiosity  \
# 0                0.12           0.01               -0.22               -0.17
# 1                0.11           0.03               -0.09               -0.10
# 2                0.04           0.26               -0.15               -0.40
# 3                0.14           0.15               -0.04               -0.17
# 4                0.12           0.24               -0.14               -0.32
# ..                ...            ...                 ...                 ...
# 113              0.10           0.07               -0.15               -0.18
# 114             -0.03           0.05               -0.05               -0.19
# 115             -0.07          -0.03               -0.00               -0.06
# 116              0.11           0.32                0.02               -0.38
# 117             -0.10            NaN                 NaN               -0.07
#
#      ethnicity_gender  ethnicity_nationalism  ethnicity_religiosity  \
# 0                0.22                  -0.02                  -0.05
# 1                0.18                    NaN                  -0.01
# 2                0.08                  -0.12                  -0.10
# 3                0.02                   0.12                  -0.02
# 4                0.20                  -0.11                  -0.08
# ..                ...                    ...                    ...
# 113              0.12                  -0.09                  -0.05
# 114              0.24                  -0.13                  -0.14
# 115              0.13                   0.07                   0.03
# 116              0.23                  -0.17                  -0.01
# 117               NaN                    NaN                  -0.10
#
#      gender_nationalism  gender_religiosity  nationalism_religiosity
# 0                  0.11               -0.10                    -0.00
# 1                 -0.03               -0.10                     0.15
# 2                 -0.05               -0.15                     0.13
# 3                 -0.07               -0.10                     0.10
# 4                 -0.09               -0.10                     0.17
# ..                  ...                 ...                      ...
# 113               -0.02                0.01                     0.08
# 114               -0.10               -0.29                     0.17
# 115                0.03                0.16                     0.22
# 116                 NaN               -0.12                    -0.07
# 117                 NaN                 NaN                      NaN
#
# [118 rows x 22 columns]

# %% [markdown]
# ## The merging_data_frames() method

# %%
CountryLevelDataVisualizer.predictors_correlations
# Out:
#      iso_numeric iso_alpha_2 iso_alpha3 country_name  authoritarian_socialism  \
# 0              8          AL        ALB      Albania                      1.0
# 1             12          DZ        DZA      Algeria                      0.5
# 2             31          AZ        AZE   Azerbaijan                      1.0
# 3             32          AR        ARG    Argentina                      0.0
# 4             36          AU        AUS    Australia                      0.0
# ..           ...         ...        ...          ...                      ...
# 101          858          UY        URY      Uruguay                      0.0
# 102          860          UZ        UZB   Uzbekistan                      1.0
# 103          862          VE        VEN    Venezuela                      0.5
# 104          887          YE        YEM        Yemen                      0.0
# 105          894          ZM        ZMB       Zambia                      0.5
#
#      culture_zone  hdi2010  v2x_libdem  population  freedom_socialism  ...  \
# 0            0.00    0.677       0.341     2913402              -0.05  ...
# 1            0.00    0.649       0.162    35856348              -0.15  ...
# 2            0.00    0.622       0.084     9237203              -0.01  ...
# 3            0.33    0.779       0.662    41100124              -0.04  ...
# 4            1.00    0.896       0.849    22019166               0.12  ...
# ..            ...      ...         ...         ...                ...  ...
# 101          0.33    0.753       0.801     3352653               0.01  ...
# 102          0.00    0.607       0.035    28614234              -0.02  ...
# 103          0.33    0.684       0.312    28715026              -0.01  ...
# 104          0.00    0.450       0.138    24743944               0.10  ...
# 105          0.00    0.418       0.388    13792095               0.07  ...
#
#      family_ethnicity  family_gender  family_nationalism  family_religiosity  \
# 0                0.12           0.01               -0.22               -0.17
# 1                0.11           0.03               -0.09               -0.10
# 2                0.14           0.15               -0.04               -0.17
# 3                0.12           0.24               -0.14               -0.32
# 4                0.16           0.45               -0.19               -0.43
# ..                ...            ...                 ...                 ...
# 101              0.21           0.29               -0.14               -0.29
# 102             -0.03           0.11                0.01                0.08
# 103              0.10           0.07               -0.15               -0.18
# 104             -0.03           0.05               -0.05               -0.19
# 105             -0.07          -0.03               -0.00               -0.06
#
#      ethnicity_gender  ethnicity_nationalism  ethnicity_religiosity  \
# 0                0.22                  -0.02                  -0.05
# 1                0.18                    NaN                  -0.01
# 2                0.02                   0.12                  -0.02
# 3                0.20                  -0.11                  -0.08
# 4                0.24                  -0.08                   0.03
# ..                ...                    ...                    ...
# 101              0.25                  -0.13                  -0.06
# 102              0.04                  -0.04                   0.01
# 103              0.12                  -0.09                  -0.05
# 104              0.24                  -0.13                  -0.14
# 105              0.13                   0.07                   0.03
#
#      gender_nationalism  gender_religiosity  nationalism_religiosity
# 0                  0.11               -0.10                    -0.00
# 1                 -0.03               -0.10                     0.15
# 2                 -0.07               -0.10                     0.10
# 3                 -0.09               -0.10                     0.17
# 4                 -0.19               -0.16                     0.00
# ..                  ...                 ...                      ...
# 101               -0.08               -0.02                     0.06
# 102               -0.06               -0.07                    -0.03
# 103               -0.02                0.01                     0.08
# 104               -0.10               -0.29                     0.17
# 105                0.03                0.16                     0.22
#
# [106 rows x 30 columns]

# %%
CountryLevelDataVisualizer.predictors_correlations.

# %% [markdown]
# ## Scatterplots

# %%
plt.scatter(x=CountryLevelDataVisualizer.predictors_correlations.hdi2010, y=CountryLevelDataVisualizer.predictors_correlations.family_ethnicity, s=CountryLevelDataVisualizer.predictors_correlations.population / 1000000)

# %%
plt.scatter(x=CountryLevelDataVisualizer.predictors_correlations.hdi2010, y=CountryLevelDataVisualizer.predictors_correlations.family_gender, s=CountryLevelDataVisualizer.predictors_correlations.population / 1000000)

# %%
plt.scatter(x=CountryLevelDataVisualizer.predictors_correlations.hdi2010, y=CountryLevelDataVisualizer.predictors_correlations.family_religiosity, s=CountryLevelDataVisualizer.predictors_correlations.population / 1000000)

# %%
plt.scatter(x=CountryLevelDataVisualizer.predictors_correlations.hdi2010, y=CountryLevelDataVisualizer.predictors_correlations.freedom_family, s=CountryLevelDataVisualizer.predictors_correlations.population / 1000000)

# %%
plt.scatter(x=CountryLevelDataVisualizer.predictors_correlations.hdi2010, y=CountryLevelDataVisualizer.predictors_correlations.gender_religiosity, s=CountryLevelDataVisualizer.predictors_correlations.population / 1000000)
